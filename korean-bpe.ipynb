# %% [markdown]
# # 한국어를 활용한 Byte-Pair Encoding
#
# 2015년 **Rico Sennrich**가 작성한 논문 [**Neural Machine Translation of Rare Words with Subword Units**](https://arxiv.org/abs/1508.07909)에서는<br/>**OOV (Out-Of-Vocabulary)** 문제를 해결하기 위해 **정보 이론**에서의 **Byte-Pair Encoding** 기법을 토크나이즈에 접목시킨 **BPE Embedding**이 고안되었습니다.
#
# 해당 알고리즘 덕분에 **자연어 처리**의 많은 모델들은 **OOV** 문제를 해결할 수 있게 되었고, 뿐만 아니라 **성능 개선**까지 얻게 되었습니다.
#
# 그리고 **BPE**를 활용한 토크나이즈 기법은 **Transformer** 기반의 여러 최신 모델들에서 아직까지 차용되고 있습니다.
#
# 본 노트북에서는 이러한 **BPE** 임베딩을 **한국어**에 적용해보며, 그 특성과 구현 방법에 대해 알아보도록 하겠습니다.

# %% [markdown]
# ## 정규표현식을 통한 전처리

# %% [markdown]
# 먼저 **정규표현식**을 활용해 한국어 문장을 전처리 해줄 수 있는 `preprocess` 함수를 구현해보도록 합시다.
#
# 한국어 전처리를 위한 정규표현식을 어떻게 구성할지는 **프로젝트의 목적**에 따라 다를 수 있습니다.
#
# 영어, 숫자 등이 의미를 큰 지니지 않는 코퍼스에 대해서는 해당 캐릭터들을 모두 제거할 수도 있겠지만, <br/>
# 영어, 숫자 등이 의미를 지니는 경우 해당 캐릭터들을 제거하지 않을 수도 있습니다.
#
# 본 예제에서는 **한국어**의 **Byte-Pair**가 어떻게 형성되는지 보기 위해 **불필요한 특수문자와 숫자, 영어를 모두 제거**하도록 하겠습니다.

# %%
import re
from collections import defaultdict
from typing import Dict, List, Tuple
from tqdm import tqdm


SPECIALS = "".join([".", ",", ";", ":", "!", "?", '"', "'", " "])


def preprocess(text: str, only_kor: bool=True):
    """한국어 문장을 옵션에 맞게 전처리"""
    # 한국어 모음과 특수 문자, 숫자 및 영어 제거
    if only_kor:
        text = re.sub(f"[^가-힣| |]+", "", text)
    else:
        text = re.sub(f"[^가-힣|ㄱ-ㅎ|0-9|{SPECIALS}|a-zA-Z|]+", "", text)
    
    # 연속 공백 제거
    text = re.sub(" +", " ", text)
    
    # 좌우 불필요한 공백 제거
    return text.strip()

# %%
sent = "ㅋㅋㅋ 안녕하세요 ! \"저는\" 10년차 original 두산 팬입니다."

# %%
preprocess(sent)
# Out:
# '안녕하세요 저는 년차 두산 팬입니다'

# %%
preprocess(sent, only_kor=False)
# Out:
# 'ㅋㅋㅋ 안녕하세요 ! "저는" 10년차 original 두산 팬입니다.'

# %% [markdown]
# ## Byte-Pair Encoding 구현
#
# 이제 전처리를 거친 문장들로 구성된 코퍼스를 활용해 **Byte-Pair**를 구성할 수 있는 **Encoding** 로직을 구현해보도록 합시다.
#
# **Byte-Pair Encoding**은 다음과 같은 **3개의 핵심 스텝**으로 구현될 수 있습니다.
#
# 1. `get_vocab`
# 2. `get_stats`
# 3. `merge_vocab`
#
# _cf. 해당 코드는 **Lei Mao**의 [포스트](https://leimao.github.io/blog/Byte-Pair-Encoding/)에서 차용 및 수정하였습니다._

# %% [markdown]
# 3개의 스텝 중 첫 번째 스텝인 `get_vocab` 함수에 대해 먼저 살펴봅시다.
#
# 해당 함수가 수행하는 로직은 간단합니다.
#
# 1. 코퍼스 파일을 **라인 단위**로 읽어옵니다.
# 2. 각 라인을 **공백 단위로 스플릿**해 토큰 리스트를 구성합니다.
# 3. 토큰 리스트를 순회하며, 토큰을 **캐릭터 단위로 자른 후** 사전에 postfix `</w>`와 함께 등록 (혹은 +1) 합니다.
#
# _cf. 논문에서는 공백과 함께 `</w>`를 끝에 더해주었지만, 0.2 버전 이후로는 공백 없이 `</w>`를 붙여줍니다._
#
# _Since 0.2, **end-of-word tokens are initially concatenated** with the word-final character:_
#
# ```
# u n d</w>
# f u n d</w>
# ```
#
# _The new representation ensures that when BPE codes are learned from the above examples and then applied to new text, it is clear that a subword unit `und` is unambiguously word-final, and `un` is unambiguously word-internal, **preventing the production of up to two different subword units from each BPE merge operation.**_

# %%
def get_vocab(f_name: str) -> Dict[str, int]:
    """코퍼스 파일을 읽어와 단어 사전 구축"""
    vocab = defaultdict(int)
    with open(f_name, "r", encoding="utf-8") as corpus:
        for line in corpus:
            tokens = preprocess(line).strip().split()
            for token in tokens:
                vocab[" ".join(list(token)) + "</w>"] += 1
    return dict(vocab)

# %% [markdown]
# 전체 코퍼스를 활용해 사전을 구축하기 전에, 간단한 **더미 데이터**로 실험을 하기 위한 `pseudo_get_vocab` 함수를 구현해주겠습니다.

# %%
def pseudo_get_vocab(corpus: List[str]) -> Dict[str, int]:
    """더미 데이터를 읽어와 단어 사전 구축"""
    vocab = defaultdict(int)
    for line in corpus:
        tokens = preprocess(line).strip().split(" ")
        for token in tokens:
            vocab[" ".join(list(token)) + " </w>"] += 1
    return dict(vocab)

# %%
corpus = [
    "기술을 사랑해",
    "축구를 사랑해",
    "한국을 사랑해",
    "야구는 사랑하지 않아",
    "삽질은 사랑하지 않아",
    "내가 사랑하는 너",
    "네가 사랑하는 나"
]

# %%
vocab = pseudo_get_vocab(corpus)
vocab
# Out:
# {'기 술 을 </w>': 1,
#  '사 랑 해 </w>': 3,
#  '축 구 를 </w>': 1,
#  '한 국 을 </w>': 1,
#  '야 구 는 </w>': 1,
#  '사 랑 하 지 </w>': 2,
#  '않 아 </w>': 2,
#  '삽 질 은 </w>': 1,
#  '내 가 </w>': 1,
#  '사 랑 하 는 </w>': 2,
#  '너 </w>': 1,
#  '네 가 </w>': 1,
#  '나 </w>': 1}

# %% [markdown]
# 이제 구축된 사전을 순회하며 사전 내 등록된 **캐릭터 토큰**과 **등장 횟수**를 반환해주는 함수 `get_tokens`를 구현해줍니다.
#
# 이후, **Byte-Pair Encoding** 로직을 거치기 이전의 사전을 확인합니다.

# %%
def get_tokens(vocab: Dict[str, int]):
    """사전 내 등록된 토큰을 확인"""
    result = defaultdict(int)
    for word, freq in vocab.items():
        tokens = word.split()
        for token in tokens:
            result[token] += freq
    return dict(result)

# %%
tokens = get_tokens(vocab)
tokens
# Out:
# {'기': 1,
#  '술': 1,
#  '을': 2,
#  '</w>': 18,
#  '사': 7,
#  '랑': 7,
#  '해': 3,
#  '축': 1,
#  '구': 2,
#  '를': 1,
#  '한': 1,
#  '국': 1,
#  '야': 1,
#  '는': 3,
#  '하': 4,
#  '지': 2,
#  '않': 2,
#  '아': 2,
#  '삽': 1,
#  '질': 1,
#  '은': 1,
#  '내': 1,
#  '가': 2,
#  '너': 1,
#  '네': 1,
#  '나': 1}

# %% [markdown]
# 마지막 스텝인 `merge_vocab`은 **가장 자주 등장했던 바이그램 페어**를 엮어주는 함수여야하므로,
#
# **가장 자주 등장한 페어**를 구할 수 있는 로직 `get_stats` 함수가 필요합니다.

# %%
def get_stats(vocab: Dict[str, int]):
    """사전을 활용한 바이그램 페어 구축"""
    pairs = defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[symbols[i],symbols[i+1]] += freq
    return dict(pairs)

# %%
pairs = get_stats(vocab)
pairs
# Out:
# {('기', '술'): 1,
#  ('술', '을'): 1,
#  ('을', '</w>'): 2,
#  ('사', '랑'): 7,
#  ('랑', '해'): 3,
#  ('해', '</w>'): 3,
#  ('축', '구'): 1,
#  ('구', '를'): 1,
#  ('를', '</w>'): 1,
#  ('한', '국'): 1,
#  ('국', '을'): 1,
#  ('야', '구'): 1,
#  ('구', '는'): 1,
#  ('는', '</w>'): 3,
#  ('랑', '하'): 4,
#  ('하', '지'): 2,
#  ('지', '</w>'): 2,
#  ('않', '아'): 2,
#  ('아', '</w>'): 2,
#  ('삽', '질'): 1,
#  ('질', '은'): 1,
#  ('은', '</w>'): 1,
#  ('내', '가'): 1,
#  ('가', '</w>'): 2,
#  ('하', '는'): 2,
#  ('너', '</w>'): 1,
#  ('네', '가'): 1,
#  ('나', '</w>'): 1}

# %% [markdown]
# 이제 3개 스텝 중 **마지막 함수**인 `merge_vocab` 함수를 구현해줍니다.
#
# `merge_vocab`의 로직 역시 간단합니다.
#
# 1. `get_stats` 함수를 통해 얻어진 바이그램 중 **가장 자주 등장한 페어**와 **기존 사전**을 인자로 받습니다.
# 2. 기존 사전에서 **캐릭터 단위**로 떨어져 있던 **바이그램을 하나의 페어**로 엮어줍니다.
# 3. **새로이 구축한 사전**을 반환합니다.

# %%
def merge_vocab(pair: Tuple[str, str], vocab: Dict[str, int]):
    """가장 자주 등장한 바이그램 페어를 엮어줌"""
    result = defaultdict(int)
    for word in vocab:
        paired = word.replace(" ".join(pair), "".join(pair))
        result[paired] = vocab[word]
    return dict(result)

# %% [markdown]
# 지금까지 구현한 함수들을 활용해 자주 등장한 **Byte-Pair**가 합쳐져, 새로운 사전이 구축되는 과정을 살펴보도록 합시다.
#
# _cf. `num_merges` 인자에 따라 **사전의 전체 크기** 등을 조정할 수 있습니다._

# %%
num_merges = 5

for i in range(num_merges):
    pairs = get_stats(vocab)
    if not pairs:
        break
    best = max(pairs, key=pairs.get)
    vocab = merge_vocab(best, vocab)
    tokens = get_tokens(vocab)
    print(f"Iter: {i+1}\n"
          f"Best pair: {best}\n"
          f"Tokens: {tokens}\n"
          f"Number of tokens: {len(tokens)}\n")
# Out:
# Iter: 1
# Best pair: ('사', '랑')
# Tokens: {'기': 1, '술': 1, '을': 2, '</w>': 18, '사랑': 7, '해': 3, '축': 1, '구': 2, '를': 1, '한': 1, '국': 1, '야': 1, '는': 3, '하': 4, '지': 2, '않': 2, '아': 2, '삽': 1, '질': 1, '은': 1, '내': 1, '가': 2, '너': 1, '네': 1, '나': 1}
# Number of tokens: 25
#
# Iter: 2
# Best pair: ('사랑', '하')
# Tokens: {'기': 1, '술': 1, '을': 2, '</w>': 18, '사랑': 3, '해': 3, '축': 1, '구': 2, '를': 1, '한': 1, '국': 1, '야': 1, '는': 3, '사랑하': 4, '지': 2, '않': 2, '아': 2, '삽': 1, '질': 1, '은': 1, '내': 1, '가': 2, '너': 1, '네': 1, '나': 1}
# Number of tokens: 25
#
# Iter: 3
# Best pair: ('사랑', '해')
# Tokens: {'기': 1, '술': 1, '을': 2, '</w>': 18, '사랑해': 3, '축': 1, '구': 2, '를': 1, '한': 1, '국': 1, '야': 1, '는': 3, '사랑하': 4, '지': 2, '않': 2, '아': 2, '삽': 1, '질': 1, '은': 1, '내': 1, '가': 2, '너': 1, '네': 1, '나': 1}
# Number of tokens: 24
#
# Iter: 4
# Best pair: ('사랑해', '</w>')
# Tokens: {'기': 1, '술': 1, '을': 2, '</w>': 15, '사랑해</w>': 3, '축': 1, '구': 2, '를': 1, '한': 1, '국': 1, '야': 1, '는': 3, '사랑하': 4, '지': 2, '않': 2, '아': 2, '삽': 1, '질': 1, '은': 1, '내': 1, '가': 2, '너': 1, '네': 1, '나': 1}
# Number of tokens: 24
#
# Iter: 5
# Best pair: ('는', '</w>')
# Tokens: {'기': 1, '술': 1, '을': 2, '</w>': 12, '사랑해</w>': 3, '축': 1, '구': 2, '를': 1, '한': 1, '국': 1, '야': 1, '는</w>': 3, '사랑하': 4, '지': 2, '않': 2, '아': 2, '삽': 1, '질': 1, '은': 1, '내': 1, '가': 2, '너': 1, '네': 1, '나': 1}
# Number of tokens: 24

# %% [markdown]
# 이제 제대로 된 훈련 파일을 읽어와 `vocab`을 구축해보도록 합시다.
#
# 훈련 파일로는 [**NSMC**](https://github.com/e9t/nsmc)의 훈련 데이터셋을 이용하도록 하겠습니다.

# %%
vocab = get_vocab("data/ratings_train.txt")
vocab
# Out:
# {'아</w>': 1701,
#  '더 빙</w>': 128,
#  '진 짜</w>': 6280,
#  '짜 증 나 네 요</w>': 17,
#  '목 소 리</w>': 108,
#  '흠 포 스 터 보 고</w>': 1,
#  '초 딩 영 화 줄 오 버 연 기 조 차</w>': 1,
#  '가 볍 지</w>': 17,
#  '않 구 나</w>': 2,
#  '너 무 재 밓 었 다 그 래 서 보 는 것 을 추 천 한 다</w>': 1,
#  '교 도 소</w>': 4,
#  '이 야 기 구 먼</w>': 1,
#  '솔 직 히</w>': 946,
#  '재 미 는</w>': 294,
#  '없 다 평 점</w>': 1,
#  '조 정</w>': 11,
#  '사 이 몬 페 그 의</w>': 1,
#  '익 살 스 런</w>': 2,
#  '연 기 가</w>': 747,
#  '돋 보 였 던</w>': 23,
#  '영 화 스 파 이 더 맨 에 서</w>': 1,
#  '늙 어 보 이 기 만</w>': 1,
#  '했 던</w>': 138,
#  '커 스 틴</w>': 4,
#  '던 스 트 가</w>': 1,
#  '너 무 나 도</w>': 193,
#  '이 뻐 보 였 다</w>': 1,
#  '막</w>': 192,
#  '걸 음 마</w>': 1,
#  '뗀</w>': 2,
#  '세 부 터</w>': 1,
#  '초 등 학 교</w>': 53,
#  '학 년 생 인</w>': 1,
#  '살 용 영 화 별 반 개 도</w>': 1,
#  '아 까 움</w>': 263,
#  '원 작 의</w>': 110,
#  '긴 장 감 을</w>': 56,
#  '제 대 로</w>': 653,
#  '살 려 내 지 못 했 다</w>': 1,
#  '별</w>': 737,
#  '반 개 도</w>': 97,
#  '아 깝 다</w>': 1196,
#  '욕 나 온 다</w>': 35,
#  '이 응 경</w>': 3,
#  '길 용 우</w>': 1,
#  '연 기 생 활 이 몇 년 인 지 정 말</w>': 1,
#  '발 로 해 도</w>': 1,
#  '그 것 보 단</w>': 4,
#  '낫 겟 다</w>': 2,
#  '납 치 감 금 만 반 복 반 복 이 드 라 마 는</w>': 1,
#  '가 족 도 없 다</w>': 1,
#  '연 기 못 하 는 사 람 만 모 엿 네</w>': 1,
#  '액 션 이</w>': 158,
#  '없 는 데 도</w>': 5,
#  '재 미</w>': 788,
#  '있 는</w>': 1768,
#  '몇 안 되 는</w>': 22,
#  '영 화</w>': 17983,
#  '왜 케</w>': 99,
#  '평 점 이</w>': 1615,
#  '낮 은 건 데</w>': 1,
#  '꽤</w>': 358,
#  '볼 만 한 데</w>': 36,
#  '헐 리 우 드 식</w>': 12,
#  '화 려 함 에 만</w>': 1,
#  '너 무</w>': 8318,
#  '길 들 여 져</w>': 3,
#  '있 나</w>': 123,
#  '걍 인 피 니 트 가 짱 이 다 진 짜 짱 이 다</w>': 1,
#  '볼 때 마 다</w>': 163,
#  '눈 물 나 서</w>': 2,
#  '죽 겠 다 년 대 의</w>': 1,
#  '향 수 자 극 허 진 호 는</w>': 1,
#  '감 성 절 제 멜 로 의</w>': 1,
#  '달 인 이 다</w>': 3,
#  '울 면 서</w>': 55,
#  '손 들 고</w>': 1,
#  '횡 단 보 도</w>': 1,
#  '건 널 때</w>': 1,
#  '뛰 쳐 나 올 뻔</w>': 1,
#  '이 범 수</w>': 19,
#  '연 기</w>': 1599,
#  '드 럽 게 못 해</w>': 1,
#  '담 백 하 고</w>': 11,
#  '깔 끔 해 서</w>': 5,
#  '좋 다</w>': 828,
#  '신 문 기 사 로 만</w>': 1,
#  '보 다</w>': 625,
#  '보 면</w>': 1200,
#  '자 꾸</w>': 209,
#  '잊 어 버 린 다</w>': 1,
#  '그 들 도</w>': 10,
#  '사 람 이 었 다 는</w>': 1,
#  '것 을</w>': 366,
#  '취 향 은</w>': 34,
#  '존 중 한 다 지 만</w>': 1,
#  '내 생 에</w>': 63,
#  '극 장 에 서</w>': 416,
#  '본</w>': 2308,
#  '영 화 중</w>': 355,
#  '가 장</w>': 1184,
#  '노 잼</w>': 247,
#  '노 감 동 임</w>': 1,
#  '스 토 리 도</w>': 586,
#  '어 거 지 고</w>': 2,
#  '감 동 도</w>': 328,
#  '어 거 지</w>': 24,
#  '냥</w>': 2,
#  '매 번</w>': 48,
#  '긴 장 되 고</w>': 8,
#  '재 밋 음</w>': 69,
#  '참</w>': 1708,
#  '사 람 들</w>': 283,
#  '웃 긴 게</w>': 11,
#  '바 스 코 가</w>': 2,
#  '이 기 면</w>': 5,
#  '락 스 코 라 고</w>': 1,
#  '까 고 바 비 가</w>': 1,
#  '아 이 돌 이 라 고</w>': 1,
#  '깐 다 그 냥</w>': 1,
#  '까 고 싶 어 서</w>': 1,
#  '안 달 난 것 처 럼</w>': 1,
#  '보 인 다</w>': 107,
#  '굿 바 이</w>': 14,
#  '레 닌</w>': 3,
#  '표 절 인 것 은</w>': 1,
#  '이 해 하 는 데</w>': 6,
#  '왜</w>': 3388,
#  '뒤 로</w>': 89,
#  '갈 수 록</w>': 391,
#  '재 미 없 어 지 냐</w>': 1,
#  '이 건</w>': 1977,
#  '정 말</w>': 8060,
#  '깨 알</w>': 7,
#  '캐 스 팅 과</w>': 12,
#  '질 퍽 하 지 않 은</w>': 1,
#  '산 뜻 한</w>': 6,
#  '내 용 구 성 이</w>': 2,
#  '잘</w>': 2661,
#  '버 무 러 진</w>': 2,
#  '깨 알 일 드</w>': 1,
#  '약 탈 자 를</w>': 1,
#  '위 한</w>': 410,
#  '변 명</w>': 7,
#  '이 라</w>': 19,
#  '저 놈 들 은</w>': 1,
#  '착 한 놈 들</w>': 1,
#  '절 대</w>': 495,
#  '아 닌 걸 요</w>': 1,
#  '나 름</w>': 539,
#  '심 오 한</w>': 29,
#  '뜻 도</w>': 7,
#  '듯</w>': 721,
#  '그 냥</w>': 3343,
#  '학 생 이</w>': 7,
#  '선 생 과</w>': 2,
#  '놀 아 나 는</w>': 9,
#  '영 화 는</w>': 2470,
#  '아 님</w>': 315,
#  '보 면 서</w>': 571,
#  '웃 지</w>': 13,
#  '않 는</w>': 583,
#  '건</w>': 416,
#  '불 가 능 하 다</w>': 7,
#  '재 미 없 다</w>': 621,
#  '지 루 하 고</w>': 526,
#  '같 은</w>': 1040,
#  '음 식</w>': 19,
#  '영 화 인 데 도</w>': 29,
#  '바 베 트 의</w>': 1,
#  '만 찬 하 고</w>': 1,
#  '넘</w>': 914,
#  '차 이 남 바 베 트 의</w>': 1,
#  '만 찬 은</w>': 1,
#  '이 야 기 도</w>': 33,
#  '있 고</w>': 417,
#  '보 는 재 미 도</w>': 3,
#  '있 는 데</w>': 247,
#  '볼 게 없 다</w>': 9,
#  '음 식 도</w>': 1,
#  '별 로</w>': 951,
#  '안 나 오 고</w>': 34,
#  '핀 란 드</w>': 4,
#  '풍 경 이 라 도</w>': 1,
#  '구 경 할 랫 는 데</w>': 1,
#  '그 것 도</w>': 75,
#  '안 나 옴</w>': 44,
#  '평 범 한</w>': 156,
#  '영 화 가</w>': 2467,
#  '아 닌</w>': 611,
#  '수 작 이 라 는 걸</w>': 1,
#  '말 씀 드 립 니 다</w>': 2,
#  '주 제 는</w>': 39,
#  '좋 은 데</w>': 317,
#  '중 반 부 터</w>': 39,
#  '지 루 하 다</w>': 387,
#  '다</w>': 2671,
#  '짤 랐 을 꺼 야</w>': 1,
#  '그 래 서</w>': 382,
#  '납 득 할</w>': 4,
#  '수</w>': 2951,
#  '없 었 던 거 야</w>': 1,
#  '그 럴 꺼 야</w>': 1,
#  '꼭</w>': 1204,
#  '그 랬 던 걸 꺼 야</w>': 1,
#  '고 추 를</w>': 1,
#  '털 어 버 려 야</w>': 1,
#  '할 텐 데</w>': 15,
#  '카 밀 라 벨</w>': 3,
#  '발 연 기</w>': 154,
#  '재 밋 는 뎅</w>': 1,
#  '센 스 있 는</w>': 9,
#  '연 출 력 탁 월 한</w>': 1,
#  '캐 스 팅 년 대 의</w>': 1,
#  '향 수</w>': 6,
#  '점</w>': 2872,
#  '엄 포 스 의</w>': 1,
#  '위 력 을</w>': 4,
#  '다 시</w>': 1596,
#  '한 번</w>': 573,
#  '깨 닫 게</w>': 82,
#  '해 준</w>': 152,
#  '적 남</w>': 1,
#  '꽃 검 사 님 도</w>': 1,
#  '좋 았 어 요</w>': 205,
#  '완 전</w>': 1826,
#  '명 품 드 라 마</w>': 6,
#  '졸 쓰 레 기</w>': 1,
#  '진 부 하 고 말 도 안 됌</w>': 1,
#  '아 시 간 아 까 워</w>': 2,
#  '재 밌 는 데</w>': 237,
#  '별 점 이</w>': 49,
#  '왜 이 리</w>': 194,
#  '낮 은 고</w>': 1,
#  '라 도</w>': 9,
#  '기 대 했 던</w>': 31,
#  '내 가</w>': 2029,
#  '죄 인 입 니 다</w>': 2,
#  '아 직 도</w>': 619,
#  '이</w>': 5207,
#  '드 라 마 는</w>': 170,
#  '내 인 생 의</w>': 15,
#  '최 고</w>': 1487,
#  '패 션 에</w>': 2,
#  '대 한</w>': 942,
#  '열 정</w>': 19,
#  '안 나</w>': 20,
#  '윈 투 어</w>': 1,
#  '키 이 라</w>': 10,
#  '나 이 틀 리 가</w>': 2,
#  '연 기 하 고 자</w>': 1,
#  '했 던 건</w>': 3,
#  '대 체</w>': 348,
#  '정 신 장 애 일 까</w>': 1,
#  '틱 장 애 일 까</w>': 1,
#  '허 허 원 작 가</w>': 1,
#  '정 신 나 간</w>': 27,
#  '유 령 이 라</w>': 1,
#  '재 미 있 겠 네 요</w>': 2,
#  '포 스 터 는</w>': 29,
#  '있 어 보 이 는 데</w>': 1,
#  '관 객 은</w>': 19,
#  '명 이 네</w>': 1,
#  '이 렇 게</w>': 1835,
#  '저 평 가</w>': 20,
#  '받 는 지</w>': 5,
#  '모 르 겠 다</w>': 404,
#  '단 순 하 면 서</w>': 2,
#  '은 은 한</w>': 20,
#  '매 력 의</w>': 16,
#  '알 바 생 인 가</w>': 4,
#  '내 용 도</w>': 644,
#  '없 고</w>': 1274,
#  '무 서 운 거 도</w>': 1,
#  '웃 긴 거 도</w>': 1,
#  '하 나 도</w>': 422,
#  '없 음</w>': 500,
#  '별 싱 거 운</w>': 1,
#  '영 화 내 시 간</w>': 1,
#  '낚 임</w>': 21,
#  '오 게 두 어 라</w>': 1,
#  '서 리 한 이</w>': 1,
#  '굶 주 렸 다</w>': 1,
#  '맘 에</w>': 256,
#  '들 어 요</w>': 15,
#  '또</w>': 1247,
#  '보 고 싶 은 데</w>': 48,
#  '보 는</w>': 1609,
#  '방 법 이</w>': 27,
#  '없 네</w>': 218,
#  '윤 제 문 이 라 는</w>': 1,
#  '멋 진</w>': 451,
#  '배 우 를</w>': 94,
#  '발 견 하 게</w>': 7,
#  '됐 어 요</w>': 16,
#  '소 소 한</w>': 76,
#  '일 탈 이</w>': 3,
#  '잔 잔 한</w>': 319,
#  '미 소 를</w>': 30,
#  '머 금 게</w>': 3,
#  '합 니 다</w>': 244,
#  '음 악 은</w>': 51,
#  '조 금</w>': 478,
#  '아 쉽 네 요</w>': 98,
#  '주 고</w>': 311,
#  '싶 은 데</w>': 95,
#  '평 점</w>': 1810,
#  '올 리 고</w>': 13,
#  '싶 어</w>': 53,
#  '줄 게 요</w>': 2,
#  '평 점 에 속 지 마 시 길 시 간 낭 비</w>': 1,
#  '돈 낭 비 임</w>': 2,
#  '리 얼 리 티 가</w>': 14,
#  '뛰 어 나 긴</w>': 1,
#  '한 데</w>': 123,
#  '큰</w>': 376,
#  '공 감 은</w>': 22,
#  '안 간 다</w>': 69,
#  '이 민 기 캐 릭 터 는</w>': 1,
#  '정 신 의 학 상</w>': 1,
#  '분 노 조 절 장 애</w>': 2,
#  '초 기</w>': 12,
#  '증 상 일 거 다</w>': 1,
#  '툭 하 면</w>': 12,
#  '사 람 패 고</w>': 2,
#  '욕 하 고</w>': 24,
#  '물 건</w>': 2,
#  '파 손 하 고</w>': 1,
#  '오 바 였 음</w>': 2,
#  '극</w>': 24,
#  '초 반 엔</w>': 47,
#  '신 선 했 는 데</w>': 7,
#  '가 면</w>': 58,
#  '이 민 기</w>': 14,
#  '정 신 상 태</w>': 4,
#  '공 감 불 가</w>': 2,
#  '마 이 너 스 는</w>': 23,
#  '왜 없 냐</w>': 2,
#  '뮤 비</w>': 6,
#  '보 고</w>': 2628,
#  '영 화 수 준</w>': 7,
#  '딱</w>': 566,
#  '알 만 하 더 군</w>': 1,
#  '북 한 에 서</w>': 5,
#  '이 런 거</w>': 157,
#  '만 들 라 고</w>': 8,
#  '돈</w>': 400,
#  '대 주 던</w>': 1,
#  '난</w>': 1427,
#  '우 리 영 화 를</w>': 1,
#  '사 랑 합 니 다</w>': 61,
#  '데 너 리 스</w>': 1,
#  '타 르</w>': 2,
#  '가 르 엔 나 도</w>': 1,
#  '용 의 주 인 이</w>': 1,
#  '되 고</w>': 119,
#  '싶 다 누 이 랑 근 친 상 간 이 나</w>': 1,
#  '하 고</w>': 812,
#  '다 닐 지 라 도 소 설</w>': 1,
#  '속 에 선</w>': 2,
#  '제 일</w>': 645,
#  '놈 이</w>': 23,
#  '자 이 메</w>': 1,
#  '라 니 스 터 였 는 데 드 라 마 속 에 선 드 래 곤 용 이</w>': 1,
#  '멋 지 네 웃 음 감 독 님</w>': 1,
#  '토 르</w>': 10,
#  '다 크</w>': 13,
#  '월 드 는</w>': 1,
#  '말 아</w>': 12,
#  '잡 수 셨 을 지 라 도 기 본</w>': 1,
#  '선 방 은</w>': 1,
#  '했 음</w>': 63,
#  '사 람 의</w>': 148,
#  '영 혼 을</w>': 27,
#  '어 루 만 져</w>': 2,
#  '줄</w>': 520,
#  '수 도</w>': 131,
#  '있 군 요</w>': 13,
#  '거 친</w>': 19,
#  '세 상 사 를</w>': 1,
#  '잠 시</w>': 45,
#  '잊 고</w>': 57,
#  '동 화 같 은</w>': 45,
#  '영 화 에</w>': 648,
#  '행 복 했 네 요</w>': 1,
#  '야</w>': 83,
#  '세 르 게 이</w>': 6,
#  '작 은 고 추 의</w>': 2,
#  '매 운 맛 을</w>': 4,
#  '보 여 주 마</w>': 4,
#  '포 퐁 저 그</w>': 1,
#  '콩 진 호 가</w>': 5,
#  '간 다</w>': 93,
#  '가 슴 시 리 게</w>': 1,
#  '드 라 마 가</w>': 185,
#  '있 을 까</w>': 289,
#  '감 동</w>': 686,
#  '그</w>': 2442,
#  '자 체</w>': 104,
#  '난 또</w>': 6,
#  '저</w>': 342,
#  '꼬 마 애 가</w>': 3,
#  '무 슨</w>': 1054,
#  '원 한 이</w>': 2,
#  '깊 길 래</w>': 1,
#  '했 더 니</w>': 51,
#  '혼 자</w>': 177,
#  '나 대 다</w>': 1,
#  '걸</w>': 329,
#  '어 쩌 라 고</w>': 34,
#  '재 미 있 어 요</w>': 288,
#  '전</w>': 455,
#  '좋 아 요</w>': 399,
#  '충 격 적 이 엇 다</w>': 1,
#  '기 분 을</w>': 16,
#  '완 전 히</w>': 109,
#  '푹</w>': 89,
#  '꺼 지 게</w>': 2,
#  '하 는</w>': 1266,
#  '느 낌</w>': 660,
#  '활 력 이 라 고 는</w>': 1,
#  '없 는</w>': 2028,
#  '무 거 운 지 독 하 고</w>': 1,
#  '차 갑 고</w>': 7,
#  '무 자 비 하 다</w>': 1,
#  '그 저</w>': 466,
#  '일 본 인 들 의</w>': 3,
#  '상 상 력 은</w>': 14,
#  '대 단 한 거</w>': 3,
#  '같 다 는</w>': 24,
#  '생 각 이</w>': 462,
#  '든 다</w>': 160,
#  '심 심 한 영 화</w>': 2,
#  '백 봉 기</w>': 1,
#  '언 제 나 오 나 요</w>': 2,
#  '보 는 내 내</w>': 486,
#  '그 대 로</w>': 275,
#  '들 어 맞 는</w>': 6,
#  '예 측</w>': 14,
#  '카 리 스 마</w>': 48,
#  '악 역</w>': 35,
#  '불 알 이</w>': 1,
#  '나 와 서</w>': 308,
#  '당 황 아 무 튼</w>': 1,
#  '중 간 에</w>': 311,
#  '끝 나 는</w>': 100,
#  '평 범 함 속 에</w>': 3,
#  '녹 아 든</w>': 6,
#  '일 상</w>': 27,
#  '밋 밋 한 게</w>': 2,
#  '흠</w>': 134,
#  '보 던 거 라</w>': 1,
#  '계 속 보 고 있 는 데</w>': 1,
#  '전 개 도</w>': 101,
#  '느 리 고</w>': 32,
#  '주 인 공 인</w>': 19,
#  '은 희 는</w>': 1,
#  '한 두 컷</w>': 1,
#  '나 오 면 서</w>': 21,
#  '소 극 적 인 모 습 에</w>': 1,
#  '짜 증 이</w>': 60,
#  '맨 날</w>': 100,
#  '언 제 끝 나 나</w>': 4,
#  '기 대 만 하 고 있 어 요</w>': 1,
#  '전 개 좀</w>': 1,
#  '빨 리 빨 리</w>': 4,
#  '사 랑 하 고 싶 게 하 는 가 슴 속 온 감 정 을 헤 집 어 놓 는 영 화 예 요 정 말 최 고</w>': 1,
#  '많 은</w>': 748,
#  '사 람 들 이</w>': 332,
#  '다 큐 를</w>': 36,
#  '우 리 나 라</w>': 304,
#  '슬 픈</w>': 166,
#  '현 대 사 의</w>': 3,
#  '한</w>': 1354,
#  '단 면 에</w>': 3,
#  '대 해</w>': 335,
#  '깊 이</w>': 85,
#  '생 각 하 고</w>': 116,
#  '사 죄 하 고</w>': 1,
#  '바 로</w>': 315,
#  '잡 기</w>': 3,
#  '위 해</w>': 422,
#  '노 력 했 으 면</w>': 1,
#  '말 로 만</w>': 8,
#  '듣 던</w>': 7,
#  '보 도 연 맹</w>': 1,
#  '민 간 인</w>': 5,
#  '학 살 이</w>': 2,
#  '이 정 도</w>': 110,
#  '일</w>': 102,
#  '줄 이 야</w>': 46,
#  '명 백 한</w>': 14,
#  '살 인 입 니 다</w>': 1,
#  '살 인 자 들 은</w>': 1,
#  '어 디 있 나 요</w>': 1,
#  '예 전</w>': 72,
#  '작 품</w>': 954,
#  '캐 릭 터</w>': 225,
#  '에 피 소 드</w>': 40,
#  '재 탕</w>': 11,
#  '삼 탕</w>': 3,
#  '사 골 우 려 먹 듯</w>': 1,
#  '우 리 고</w>': 2,
#  '내 용 은</w>': 396,
#  '산 으 로</w>': 107,
#  '가 고</w>': 67,
#  '시 청 률 은</w>': 16,
#  '아 예 안 나 오 고</w>': 1,
#  '이 제</w>': 493,
#  '회 중 반 인 데</w>': 1,
#  '부 작 이 라 니</w>': 2,
#  '김 남 길 의</w>': 3,
#  '백 점 짜 리</w>': 1,
#  '연 기 력 과</w>': 42,
#  '초 반</w>': 116,
#  '몰 입 도 에 도</w>': 1,
#  '불 구 하 고</w>': 133,
#  '손 예 진</w>': 17,
#  '재 밌 네</w>': 112,
#  '비 슷 한</w>': 175,
#  '영 화 를</w>': 2803,
#  '안 보 신</w>': 9,
#  '분 들 한 테 는</w>': 1,
#  '재 미 있 을</w>': 26,
#  '노 래 실 력 으 로 뽑 는 게</w>': 1,
#  '맞 냐</w>': 13,
#  '박 시 환 이</w>': 2,
#  '나 가 면</w>': 5,
#  '망 신 이 다</w>': 3,
#  '일 본 영 화</w>': 82,
#  '다 이 런 건 가</w>': 1,
#  '유 치 하 다</w>': 96,
#  '이 틀 만 에</w>': 6,
#  '봤 어 요</w>': 405,
#  '재 밌 어 요</w>': 551,
#  '근 데</w>': 701,
#  '차</w>': 38,
#  '안 에</w>': 89,
#  '넣 어</w>': 18,
#  '조 작 하 려 고</w>': 1,
#  '하 면</w>': 218,
#  '안 이</w>': 2,
#  '열 려 있 다 던 지</w>': 1,
#  '집</w>': 37,
#  '활 짝</w>': 7,
#  '열 려 서</w>': 1,
#  '아 무 나</w>': 45,
#  '들 어 간 다 던 가</w>': 1,
#  '문 자 를</w>': 1,
#  '조 작 하 려 고 하 면</w>': 1,
#  '비 번 이</w>': 2,
#  '안</w>': 938,
#  '걸 려 있 고</w>': 1,
#  '그 런</w>': 512,
#  '억 지 스 러 웠 는 데</w>': 2,
#  '그 래 도</w>': 774,
#  '내 용</w>': 490,
#  '자 체 는</w>': 83,
#  '졸 작</w>': 293,
#  '재 밋 네 요</w>': 37,
#  '달 팽 이 가</w>': 3,
#  '빨 라 서</w>': 11,
#  '더</w>': 3274,
#  '재 밌 었 어 요</w>': 184,
#  '어 설 픈</w>': 341,
#  '전 개</w>': 312,
#  '어 이 없 는</w>': 161,
#  '결 말</w>': 303,
#  '부 패 한</w>': 6,
#  '로 마 노 프</w>': 1,
#  '왕 조 를</w>': 1,
#  '기 리 는</w>': 4,
#  '뭣 같 은</w>': 6,
#  '온 몸 으 로</w>': 5,
#  '항 거 했 던</w>': 1,
#  '러 시 아</w>': 32,
#  '민 중 들 이</w>': 1,
#  '폭 도 냐</w>': 1,
#  '내 용 전 개 는</w>': 3,
#  '무 난 한</w>': 19,
#  '편 이 였 구</w>': 1,
#  '보 았 습 니 다</w>': 85,
#  '매 우</w>': 429,
#  '실 망</w>': 211,
#  '한 국 영 화</w>': 204,
#  '흥 행 코 드</w>': 1,
#  '갈 등 갈 등 계 에 속</w>': 1,
#  '갈 등 화 해 감 동</w>': 1,
#  '남 발</w>': 9,
#  '흥 행</w>': 40,
#  '뻔 하 지</w>': 16,
#  '뭐</w>': 1066,
#  '아 햏 햏</w>': 3,
#  '뭐 냐 시 작 하 고</w>': 1,
#  '분 만 에</w>': 57,
#  '나 왔 다</w>': 61,
#  '리 플 릿</w>': 1,
#  '사 진</w>': 22,
#  '보 며</w>': 107,
#  '불 안 하 더 니 만</w>': 1,
#  '단 연</w>': 102,
#  '최 고 라 고</w>': 51,
#  '할 수 있 지</w>': 4,
#  '감 독 이</w>': 598,
#  '럼 먹 고</w>': 1,
#  '만 들 었 나 보 다</w>': 3,
#  '관 객 에 게</w>': 34,
#  '뭘</w>': 386,
#  '말 하 는 지 도</w>': 3,
#  '모 르 겠 고</w>': 113,
#  '엉 망 진 창</w>': 19,
#  '개 진 창 이 다</w>': 1,
#  '뭐 냐</w>': 243,
#  '우 뢰 매 냐</w>': 1,
#  '정 말 쓰 레 기 영 화 입 니 다</w>': 1,
#  '진 정</w>': 93,
#  '위 대 한</w>': 111,
#  '최 고 임</w>': 85,
#  '별 루</w>': 98,
#  '였 다</w>': 39,
#  '내 일 이</w>': 11,
#  '기 대 되 는</w>': 32,
#  '조 미 가</w>': 1,
#  '막 문 위</w>': 1,
#  '좋 아 한 건 가 요</w>': 1,
#  '골 깜</w>': 1,
#  '눈</w>': 104,
#  '부 라 릴 때</w>': 1,
#  '쓰 러 짐</w>': 1,
#  '성 룡 영 화 중</w>': 9,
#  '최 악 인 듯</w>': 9,
#  '골 때 리 네</w>': 4,
#  '걸 스 데 이</w>': 2,
#  '이 혜 리</w>': 1,
#  '되 라</w>': 7,
#  '서 기 가 이 뻐 서</w>': 1,
#  '재 밌 어 요 백 인 공 주 귀 여 움</w>': 1,
#  '인 상 적 인</w>': 59,
#  '영 화 였 다</w>': 308,
#  '어 내 스 트 와</w>': 1,
#  '셀 레 스 틴</w>': 2,
#  '강 추 에 요</w>': 5,
#  '재 밌 습 니 다</w>': 145,
#  '재 미 있 는 영 화 입 니 다</w>': 1,
#  '클 라 라 볼 라 고 화 신 본 거 아 닌 데</w>': 1,
#  '슬 펐 던</w>': 15,
#  '영 화 다</w>': 1077,
#  '설 정 이</w>': 55,
#  '재 밌 고</w>': 364,
#  '새 로 운</w>': 259,
#  '내 에 서</w>': 6,
#  '메 인</w>': 14,
#  '차 차</w>': 1,
#  '나 오 는 게</w>': 21,
#  '재 밌 음</w>': 409,
#  '신 카 이</w>': 4,
#  '마 코 토 의</w>': 1,
#  '작 화 와 미 유 와</w>': 1,
#  '하 나 카 나 가</w>': 1,
#  '연 기 를</w>': 372,
#  '잘 해 줘 서</w>': 3,
#  '더 대 박 이 였 다</w>': 1,
#  '재 미 없 음</w>': 350,
#  '진 심</w>': 510,
#  '이 훨 나</w>': 1,
#  '캐 스 팅 두 못 한 듯</w>': 1,
#  '잔 잔 한 게</w>': 9,
#  '생 각 보 다</w>': 324,
#  '볼 만 한</w>': 261,
#  '영 화 인 거</w>': 27,
#  '같 습 니 다</w>': 180,
#  '감 독 님 들</w>': 2,
#  '고 은 님</w>': 1,
#  '쓰 면</w>': 20,
#  '영 화 안 봅 니 다</w>': 1,
#  '무 섭 지 도</w>': 102,
#  '않 았 고</w>': 29,
#  '영 화 속</w>': 51,
#  '억 지 스 럽 고</w>': 50,
#  '노 골 적 인</w>': 12,
#  '술 광 고 를</w>': 1,
#  '좀</w>': 2566,
#  '은 은 하 고</w>': 3,
#  '센 스 있 게</w>': 2,
#  '했 으 면</w>': 80,
#  '어 땠 을 까</w>': 25,
#  '킬 링 타 임</w>': 53,
#  '크 리 스 마 스 하 면</w>': 2,
#  '떠 오 르 는 영 화</w>': 1,
#  '재 미 있 게</w>': 753,
#  '봤 습 니 다</w>': 527,
#  '매 력 적 인</w>': 168,
#  '행 복 이 네 요</w>': 1,
#  '음 악 에</w>': 28,
#  '빠 져 서</w>': 58,
#  '볼</w>': 959,
#  '있 었 던</w>': 158,
#  '쫌</w>': 117,
#  '산 만 하 긴</w>': 2,
#  '하 던 데</w>': 35,
#  '태 어 나 서</w>': 75,
#  '처 음 으 로</w>': 212,
#  '영 화 보 다</w>': 208,
#  '나 왔 습 니 다 불 륜 이</w>': 1,
#  '로 맨 스 냐</w>': 3,
#  '왕 짜 증 아 주</w>': 1,
#  '전 개 를</w>': 22,
#  '짬 뽕 으 로</w>': 1,
#  '믹 스 했 구 나 음 향 만</w>': 1,
#  '무 섭 게 하 네 하 아</w>': 1,
#  '별 루 더 라</w>': 1,
#  '시 간 낭 비 느 낌</w>': 1,
#  '대 박</w>': 481,
#  '시 청 률</w>': 102,
#  '기 준 이</w>': 16,
#  '되 는</w>': 452,
#  '패 널 가 구 들</w>': 1,
#  '머 하 는 거 지</w>': 1,
#  '명 작 드 라 마</w>': 2,
#  '망 치 네</w>': 10,
#  '서 운 하 다</w>': 1,
#  '내 용 이</w>': 636,
#  '이 상 해</w>': 33,
#  '몬 스 터</w>': 10,
#  '주 식 회 사</w>': 2,
#  '재 밌 게</w>': 1349,
#  '봤 다</w>': 707,
#  '내 용 전 개 가</w>': 26,
#  '너 무 나</w>': 454,
#  '느 리 다</w>': 9,
#  '소 재 는</w>': 187,
#  '흥 미 를</w>': 55,
#  '끌 지 만</w>': 2,
#  '이 야 기</w>': 695,
#  '전 개 가</w>': 251,
#  '투 박 해 서</w>': 2,
#  '몰 입 이</w>': 140,
#  '안 되 는 군</w>': 6,
#  '보 지 마 라</w>': 83,
#  '쓰 레 기</w>': 1519,
#  '중 국 인</w>': 10,
#  '특 유 의</w>': 215,
#  '과 장</w>': 7,
#  '허 풍</w>': 4,
#  '있 어 보 이 려 고</w>': 12,
#  '안 간 힘</w>': 2,
#  '쓴</w>': 135,
#  '노 력 은</w>': 21,
#  '가 상 하 나</w>': 3,
#  '고 증 과</w>': 2,
#  '현 실 감</w>': 18,
#  '떨 어 지 는</w>': 139,
#  '거 북 스 럽 다</w>': 2,
#  '도 대 체</w>': 570,
#  '그 들 은</w>': 34,
#  '이 렇 게 까 지</w>': 47,
#  '스 스 로 를</w>': 17,
#  '과 대 포 장 하 는</w>': 1,
#  '것 인 지</w>': 26,
#  '불 법 체 류 자</w>': 7,
#  '때 려 잡 는</w>': 6,
#  '영 화 면</w>': 26,
#  '좋 았 을 텐 데 무 슨</w>': 1,
#  '우 상 화 를</w>': 1,
#  '만 든 다 고</w>': 10,
#  '미 국 의</w>': 64,
#  '따 뜻 한</w>': 227,
#  '설 정 이 건</w>': 1,
#  '뭥 미</w>': 55,
#  '년 의</w>': 21,
#  '삶 속 에</w>': 3,
#  '주 인 공 의</w>': 159,
#  '생 애 가</w>': 2,
#  '전 부</w>': 235,
#  '드 러 난</w>': 16,
#  '하 다</w>': 262,
#  '별 점 점 가 자</w>': 1,
#  '별 로 다</w>': 162,
#  '본 지</w>': 70,
#  '지 난</w>': 164,
#  '후 에</w>': 57,
#  '남 기 지 만 재 미 있 었 음</w>': 1,
#  '아 니</w>': 341,
#  '이 게</w>': 1745,
#  '점 대</w>': 139,
#  '일 까</w>': 7,
#  '년 이</w>': 230,
#  '지 나</w>': 36,
#  '보 게 된</w>': 44,
#  '다 시 봐 도</w>': 242,
#  '순 수 한</w>': 165,
#  '사 랑 에</w>': 148,
#  '숀 펜 의</w>': 4,
#  '연 기 또 한</w>': 6,
#  '올 레 에</w>': 2,
#  '공 짜 로 있 길 래</w>': 1,
#  '봤 음</w>': 248,
#  '헐</w>': 164,
#  '스 토 리 가</w>': 675,
#  '문 제 가 아 니 라</w>': 1,
#  '연 기 자 들 이</w>': 16,
#  '전 혀</w>': 882,
#  '배 역 이 랑</w>': 2,
#  '어 울 리 지 않 음</w>': 1,
#  '그 리 고</w>': 1592,
#  '상 대 배 우 들 하 고</w>': 1,
#  '따 로</w>': 68,
#  '노 는 거 같 음</w>': 1,
#  '연 기 자 들 도</w>': 10,
#  '문 제 있 음</w>': 1,
#  '보 아 는</w>': 3,
#  '별 로 임</w>': 85,
#  '라 미 란 하 고</w>': 1,
#  '아 들 이</w>': 61,
#  '젤</w>': 120,
#  '볼 만 했 음</w>': 27,
#  '욕 심 이</w>': 18,
#  '많 았 던</w>': 24,
#  '어 느</w>': 194,
#  '쪽 만 이 라 도</w>': 1,
#  '보 여 줬 다 면</w>': 3,
#  '빵 점</w>': 51,
#  '베 댓 이</w>': 2,
#  '말 을</w>': 124,
#  '아 주</w>': 845,
#  '잘 써 놨 네</w>': 1,
#  '모 자 라 진</w>': 1,
#  '않 다</w>': 321,
#  '도 둑 들 이 나</w>': 2,
#  '뫼 비 우 스</w>': 3,
#  '나 라 에 서</w>': 10,
#  '만 들 어 졌 다 는 게</w>': 5,
#  '믿 어 지 냐</w>': 1,
#  '온 몸 이</w>': 6,
#  '찌 릿 짜 릿</w>': 1,
#  '나 두</w>': 15,
#  '용 기 를</w>': 21,
#  '가 져 야 지</w>': 1,
#  '정 말 재 미 있 고</w>': 2,
#  '교 훈 적 인</w>': 16,
#  '영 화 이 네 요</w>': 7,
#  '당 시 의</w>': 24,
#  '상 황 과</w>': 22,
#  '주 제 를</w>': 84,
#  '주 입 식 이</w>': 1,
#  '긴 장 감 있 고</w>': 11,
#  '전 하 는</w>': 14,
#  '케 이 블 에 서</w>': 74,
#  '그 만</w>': 226,
#  '나 와 줬 으 면</w>': 4,
#  '다 르 덴 이 냐 리 투 차 이 밍 량 이</w>': 1,
#  '안 섞 인 채</w>': 1,
#  '짬 뽕</w>': 13,
#  '그 릇 에</w>': 2,
#  '담 겨 있 다</w>': 10,
#  '여 군</w>': 4,
#  '잼 없 음</w>': 35,
#  '뭐 하 는 건 지</w>': 8,
#  '엠 비 씨</w>': 11,
#  '다 잼 없 음</w>': 1,
#  '질 린 다 이 제</w>': 1,
#  '좋 구 나</w>': 9,
#  '한 석 규</w>': 21,
#  '김 혜 수</w>': 22,
#  '연 기 만</w>': 45,
#  '돋 보 인</w>': 20,
#  '어 딘 지</w>': 5,
#  '모 르 게</w>': 105,
#  '많 이</w>': 1492,
#  '에 볼 라 바 이 러 스 가</w>': 1,
#  '떠 들 석 해 서</w>': 1,
#  '보 게 된 영 화 인 데</w>': 2,
#  '작 품 성 이 나</w>': 3,
#  '어 떤 면 에 서 도</w>': 1,
#  '여 년 전</w>': 18,
#  '영 화 라 고 보 기 엔</w>': 1,
#  '믿 기 힘 들 정 도 로</w>': 1,
#  '잘 만 들 었 다 고 본 다</w>': 1,
#  '마 지 막 후 반 부 가</w>': 1,
#  '살 짝</w>': 143,
#  '아 쉽 긴 하 지 만</w>': 5,
#  '이 정 도 면</w>': 150,
#  '수 작 이 라 고 본 다</w>': 1,
#  '시 간 이</w>': 633,
#  '아 깝 지 않 은 영 화</w>': 3,
#  '볼 만 해</w>': 10,
#  '재 미 있 다 고</w>': 30,
#  '떨 지</w>': 1,
#  '마 세 요</w>': 129,
#  '용 가 리</w>': 16,
#  '진 짜 짱 짱 맨 이 다</w>': 1,
#  '이 제 서 야</w>': 93,
#  '보 다 니</w>': 65,
#  '감 히</w>': 96,
#  '내</w>': 1616,
#  '인 생</w>': 416,
#  '최 고 의</w>': 2235,
#  '하 나 로</w>': 74,
#  '꼽 을</w>': 19,
#  '있 을 만 한</w>': 3,
#  '어 떻 게</w>': 755,
#  '살 아 야 할 지</w>': 4,
#  '나 를</w>': 176,
#  '고 민 을</w>': 18,
#  '하 게</w>': 190,
#  '시 간</w>': 812,
#  '모 건</w>': 8,
#  '프 리 먼 은</w>': 1,
#  '나 이 가</w>': 64,
#  '들 어 도</w>': 38,
#  '여 전 히</w>': 173,
#  '섹 시 하 다</w>': 15,
#  '작 가 가 별 로 다</w>': 1,
#  '내 용 이 진 짜 별 로 임</w>': 1,
#  '맨 날 그 냥 기 대 하 고</w>': 1,
#  '재 방 송 하 면</w>': 1,
#  '혹 시 나 하 고 봐 줘 도</w>': 1,
#  '답 없 다 진 짜</w>': 1,
#  '명 작 도</w>': 11,
#  '이 런</w>': 3292,
#  '명 작 이</w>': 52,
#  '싶 다</w>': 571,
#  '봐 도</w>': 911,
#  '여 운 이</w>': 576,
#  '남 는</w>': 500,
#  '조 금 만</w>': 50,
#  '손</w>': 37,
#  '왠 만 한</w>': 54,
#  '상 업</w>': 10,
#  '못 지</w>': 20,
#  '않 게</w>': 136,
#  '퀄 리 티</w>': 41,
#  '쩔 게</w>': 4,
#  '만 들 어</w>': 224,
#  '질</w>': 33,
#  '있 었 는 데</w>': 86,
#  '충 분 히</w>': 271,
#  '재 미 있 었 습 니 다</w>': 58,
#  '개 인 적 으 로</w>': 479,
#  '잔 인 하 게</w>': 27,
#  '자 극 적 으 로</w>': 9,
#  '노 출 씬 도</w>': 2,
#  '화 끈 하 게</w>': 26,
#  '했 더 라 면</w>': 6,
#  '국 산 영 화 라</w>': 1,
#  '아 낀</w>': 2,
#  '보 임</w>': 26,
#  '그 만 좀</w>': 21,
#  '끌 고</w>': 37,
#  '끝 내 라</w>': 7,
#  '지 겹 다</w>': 61,
#  '지 겨 워</w>': 20,
#  '역 시</w>': 1532,
#  '드 니 로 의</w>': 12,
#  '연 기 는</w>': 486,
#  '일 품</w>': 44,
#  '나 도</w>': 559,
#  '맥 스 가</w>': 1,
#  '샘 을</w>': 3,
#  '죽 이 길</w>': 1,
#  '바 랬 다</w>': 6,
#  '괜 찮 은</w>': 441,
#  '작 품 입 니 다</w>': 63,
#  '좋 은</w>': 1747,
#  '스 러 웟 음</w>': 1,
#  '배 우 들 은</w>': 81,
#  '지 네 들</w>': 3,
#  '안 뜨 니 까</w>': 1,
#  '이 런 영 화</w>': 163,
#  '찍 을 껀 데</w>': 1,
#  '안 뜨 는 지</w>': 1,
#  '모 르 는 거 야</w>': 1,
#  '면 상</w>': 5,
#  '알 겠 구 만</w>': 1,
#  '지 네</w>': 8,
#  '자 신 들 은</w>': 3,
#  '모 를 까</w>': 20,
#  '어 린 이 가</w>': 5,
#  '좋 아 할 듯 내 어 릴 적</w>': 1,
#  '동 심 은</w>': 3,
#  '멀 리</w>': 12,
#  '떠 낫 나 보 다</w>': 1,
#  '무 술 인 이</w>': 2,
#  '총 을 드 나</w>': 1,
#  '크 리 스 토 퍼 왈 츠 와</w>': 1,
#  '타 란 티 노 의</w>': 10,
#  '조 합 이 란</w>': 2,
#  '한 국 에 선 유 명 한 편 은 아 니 지 만</w>': 1,
#  '외 국 에 선</w>': 2,
#  '상 상 초 월 한</w>': 1,
#  '유 명 한</w>': 107,
#  '영 화 입 니 다</w>': 576,
#  '오 랜 만 에</w>': 568,
#  '재 밋 는 영 화 봤 네 요</w>': 1,
#  '종 방 되 어</w>': 1,
#  '아 쉬 워 요</w>': 44,
#  '오 늘 막 방 도</w>': 1,
#  '잘 봤 어 요 방 송 대 본 이</w>': 1,
#  '완 성 도 있 다 는</w>': 1,
#  '느 낌 받 았 고 요</w>': 1,
#  ...}

# %% [markdown]
# 구축한 사전에 `merge_vocab` 로직을 적용합니다. 간단한 실험을 위해 `num_merges`는 **1000**으로 설정하겠습니다.

# %%
num_merges = 1000

for i in tqdm(range(num_merges)):
    pairs = get_stats(vocab)
    if not pairs:
        break
    best = max(pairs, key=pairs.get)
    vocab = merge_vocab(best, vocab)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [17:15<00:00,  1.09s/it]

# %%
vocab
# Out:
# {'아</w>': 1701,
#  '더빙</w>': 128,
#  '진짜</w>': 6280,
#  '짜증 나 네요</w>': 17,
#  '목 소리</w>': 108,
#  '흠 포스터 보고</w>': 1,
#  '초딩 영화 줄 오 버 연기 조 차</w>': 1,
#  '가 볍 지</w>': 17,
#  '않 구나</w>': 2,
#  '너무 재 밓 었 다 그래 서 보는 것 을 추천 한다</w>': 1,
#  '교 도 소</w>': 4,
#  '이야기 구 먼</w>': 1,
#  '솔직히</w>': 946,
#  '재미는</w>': 294,
#  '없다 평점</w>': 1,
#  '조 정</w>': 11,
#  '사이 몬 페 그 의</w>': 1,
#  '익 살 스 런</w>': 2,
#  '연기가</w>': 747,
#  '돋 보 였 던</w>': 23,
#  '영화 스 파이 더 맨 에서</w>': 1,
#  '늙 어 보이 기 만</w>': 1,
#  '했던</w>': 138,
#  '커 스 틴</w>': 4,
#  '던 스트 가</w>': 1,
#  '너무 나도</w>': 193,
#  '이 뻐 보 였다</w>': 1,
#  '막</w>': 192,
#  '걸 음 마</w>': 1,
#  '뗀</w>': 2,
#  '세 부터</w>': 1,
#  '초 등 학교</w>': 53,
#  '학 년 생 인</w>': 1,
#  '살 용 영화 별 반 개도</w>': 1,
#  '아까움</w>': 263,
#  '원작 의</w>': 110,
#  '긴장감 을</w>': 56,
#  '제대로</w>': 653,
#  '살 려 내 지 못 했다</w>': 1,
#  '별</w>': 737,
#  '반 개도</w>': 97,
#  '아깝다</w>': 1196,
#  '욕 나온다</w>': 35,
#  '이 응 경</w>': 3,
#  '길 용 우</w>': 1,
#  '연기 생 활 이 몇 년 인 지 정말</w>': 1,
#  '발 로 해도</w>': 1,
#  '그 것 보단</w>': 4,
#  '낫 겟 다</w>': 2,
#  '납 치 감 금 만 반 복 반 복 이 드라마 는</w>': 1,
#  '가족 도 없다</w>': 1,
#  '연기 못 하는 사람 만 모 엿 네</w>': 1,
#  '액션 이</w>': 158,
#  '없는데 도</w>': 5,
#  '재미</w>': 788,
#  '있는</w>': 1768,
#  '몇 안되는</w>': 22,
#  '영화</w>': 17983,
#  '왜 케</w>': 99,
#  '평점이</w>': 1615,
#  '낮 은 건데</w>': 1,
#  '꽤</w>': 358,
#  '볼만 한데</w>': 36,
#  '헐리 우 드 식</w>': 12,
#  '화려 함 에 만</w>': 1,
#  '너무</w>': 8318,
#  '길 들 여 져</w>': 3,
#  '있 나</w>': 123,
#  '걍 인 피 니 트 가 짱 이다 진짜 짱 이다</w>': 1,
#  '볼 때마다</w>': 163,
#  '눈물 나서</w>': 2,
#  '죽 겠 다 년 대 의</w>': 1,
#  '향 수 자 극 허 진 호 는</w>': 1,
#  '감 성 절 제 멜 로 의</w>': 1,
#  '달 인 이다</w>': 3,
#  '울 면서</w>': 55,
#  '손 들 고</w>': 1,
#  '횡 단 보 도</w>': 1,
#  '건 널 때</w>': 1,
#  '뛰 쳐 나올 뻔</w>': 1,
#  '이 범 수</w>': 19,
#  '연기</w>': 1599,
#  '드 럽 게 못 해</w>': 1,
#  '담 백 하고</w>': 11,
#  '깔 끔 해서</w>': 5,
#  '좋다</w>': 828,
#  '신 문 기 사 로 만</w>': 1,
#  '보다</w>': 625,
#  '보면</w>': 1200,
#  '자 꾸</w>': 209,
#  '잊 어 버 린다</w>': 1,
#  '그 들도</w>': 10,
#  '사람 이었 다는</w>': 1,
#  '것을</w>': 366,
#  '취 향 은</w>': 34,
#  '존 중 한다 지만</w>': 1,
#  '내 생 에</w>': 63,
#  '극장에서</w>': 416,
#  '본</w>': 2308,
#  '영화중</w>': 355,
#  '가장</w>': 1184,
#  '노잼</w>': 247,
#  '노 감동 임</w>': 1,
#  '스토리도</w>': 586,
#  '어 거 지고</w>': 2,
#  '감동도</w>': 328,
#  '어 거 지</w>': 24,
#  '냥</w>': 2,
#  '매 번</w>': 48,
#  '긴장 되고</w>': 8,
#  '재밋 음</w>': 69,
#  '참</w>': 1708,
#  '사람들</w>': 283,
#  '웃 긴 게</w>': 11,
#  '바 스 코 가</w>': 2,
#  '이 기 면</w>': 5,
#  '락 스 코 라고</w>': 1,
#  '까 고 바 비 가</w>': 1,
#  '아이 돌 이라고</w>': 1,
#  '깐 다 그냥</w>': 1,
#  '까 고싶 어서</w>': 1,
#  '안 달 난 것 처럼</w>': 1,
#  '보 인 다</w>': 107,
#  '굿 바 이</w>': 14,
#  '레 닌</w>': 3,
#  '표 절 인 것은</w>': 1,
#  '이해 하는데</w>': 6,
#  '왜</w>': 3388,
#  '뒤 로</w>': 89,
#  '갈수록</w>': 391,
#  '재미없 어지 냐</w>': 1,
#  '이건</w>': 1977,
#  '정말</w>': 8060,
#  '깨 알</w>': 7,
#  '캐스팅 과</w>': 12,
#  '질 퍽 하 지않은</w>': 1,
#  '산 뜻 한</w>': 6,
#  '내용 구 성이</w>': 2,
#  '잘</w>': 2661,
#  '버 무 러 진</w>': 2,
#  '깨 알 일 드</w>': 1,
#  '약 탈 자 를</w>': 1,
#  '위한</w>': 410,
#  '변 명</w>': 7,
#  '이라</w>': 19,
#  '저 놈 들은</w>': 1,
#  '착 한 놈 들</w>': 1,
#  '절대</w>': 495,
#  '아닌 걸 요</w>': 1,
#  '나름</w>': 539,
#  '심 오 한</w>': 29,
#  '뜻 도</w>': 7,
#  '듯</w>': 721,
#  '그냥</w>': 3343,
#  '학생 이</w>': 7,
#  '선 생 과</w>': 2,
#  '놀 아 나는</w>': 9,
#  '영화는</w>': 2470,
#  '아님</w>': 315,
#  '보면서</w>': 571,
#  '웃 지</w>': 13,
#  '않는</w>': 583,
#  '건</w>': 416,
#  '불 가능 하다</w>': 7,
#  '재미없다</w>': 621,
#  '지루하고</w>': 526,
#  '같은</w>': 1040,
#  '음 식</w>': 19,
#  '영화인데 도</w>': 29,
#  '바 베 트 의</w>': 1,
#  '만 찬 하고</w>': 1,
#  '넘</w>': 914,
#  '차 이 남 바 베 트 의</w>': 1,
#  '만 찬 은</w>': 1,
#  '이야기도</w>': 33,
#  '있고</w>': 417,
#  '보는 재미도</w>': 3,
#  '있는데</w>': 247,
#  '볼 게 없다</w>': 9,
#  '음 식 도</w>': 1,
#  '별로</w>': 951,
#  '안 나오 고</w>': 34,
#  '핀 란 드</w>': 4,
#  '풍 경 이라도</w>': 1,
#  '구 경 할 랫 는데</w>': 1,
#  '그 것도</w>': 75,
#  '안 나 옴</w>': 44,
#  '평범 한</w>': 156,
#  '영화가</w>': 2467,
#  '아닌</w>': 611,
#  '수작 이라 는 걸</w>': 1,
#  '말 씀 드 립 니다</w>': 2,
#  '주제 는</w>': 39,
#  '좋은데</w>': 317,
#  '중 반 부터</w>': 39,
#  '지루하다</w>': 387,
#  '다</w>': 2671,
#  '짤 랐 을 꺼 야</w>': 1,
#  '그래서</w>': 382,
#  '납 득 할</w>': 4,
#  '수</w>': 2951,
#  '없었 던 거 야</w>': 1,
#  '그 럴 꺼 야</w>': 1,
#  '꼭</w>': 1204,
#  '그 랬 던 걸 꺼 야</w>': 1,
#  '고 추 를</w>': 1,
#  '털 어 버 려 야</w>': 1,
#  '할 텐데</w>': 15,
#  '카 밀 라 벨</w>': 3,
#  '발 연기</w>': 154,
#  '재밋 는 뎅</w>': 1,
#  '센 스 있는</w>': 9,
#  '연출 력 탁 월 한</w>': 1,
#  '캐스팅 년 대 의</w>': 1,
#  '향 수</w>': 6,
#  '점</w>': 2872,
#  '엄 포 스 의</w>': 1,
#  '위 력 을</w>': 4,
#  '다시</w>': 1596,
#  '한번</w>': 573,
#  '깨 닫 게</w>': 82,
#  '해 준</w>': 152,
#  '적 남</w>': 1,
#  '꽃 검 사 님 도</w>': 1,
#  '좋았 어요</w>': 205,
#  '완전</w>': 1826,
#  '명 품 드라마</w>': 6,
#  '졸 쓰레기</w>': 1,
#  '진부 하고 말 도 안 됌</w>': 1,
#  '아 시간 아까 워</w>': 2,
#  '재밌 는데</w>': 237,
#  '별 점이</w>': 49,
#  '왜이 리</w>': 194,
#  '낮 은 고</w>': 1,
#  '라도</w>': 9,
#  '기대 했던</w>': 31,
#  '내가</w>': 2029,
#  '죄 인 입니다</w>': 2,
#  '아직도</w>': 619,
#  '이</w>': 5207,
#  '드라마 는</w>': 170,
#  '내 인생 의</w>': 15,
#  '최고</w>': 1487,
#  '패 션 에</w>': 2,
#  '대한</w>': 942,
#  '열 정</w>': 19,
#  '안 나</w>': 20,
#  '윈 투 어</w>': 1,
#  '키 이라</w>': 10,
#  '나이 틀 리가</w>': 2,
#  '연기 하고 자</w>': 1,
#  '했 던 건</w>': 3,
#  '대체</w>': 348,
#  '정신 장 애 일 까</w>': 1,
#  '틱 장 애 일 까</w>': 1,
#  '허 허 원작가</w>': 1,
#  '정신 나 간</w>': 27,
#  '유 령 이라</w>': 1,
#  '재미있 겠 네요</w>': 2,
#  '포스터 는</w>': 29,
#  '있어 보이 는데</w>': 1,
#  '관객 은</w>': 19,
#  '명 이네</w>': 1,
#  '이렇게</w>': 1835,
#  '저 평가</w>': 20,
#  '받 는지</w>': 5,
#  '모르겠다</w>': 404,
#  '단순 하면서</w>': 2,
#  '은 은 한</w>': 20,
#  '매력 의</w>': 16,
#  '알바 생 인가</w>': 4,
#  '내용도</w>': 644,
#  '없고</w>': 1274,
#  '무서 운 거 도</w>': 1,
#  '웃 긴 거 도</w>': 1,
#  '하나도</w>': 422,
#  '없음</w>': 500,
#  '별 싱 거 운</w>': 1,
#  '영화 내 시간</w>': 1,
#  '낚 임</w>': 21,
#  '오 게 두 어 라</w>': 1,
#  '서 리 한 이</w>': 1,
#  '굶 주 렸다</w>': 1,
#  '맘 에</w>': 256,
#  '들어요</w>': 15,
#  '또</w>': 1247,
#  '보고싶 은데</w>': 48,
#  '보는</w>': 1609,
#  '방 법 이</w>': 27,
#  '없네</w>': 218,
#  '윤 제 문 이라는</w>': 1,
#  '멋진</w>': 451,
#  '배우 를</w>': 94,
#  '발 견 하게</w>': 7,
#  '됐 어요</w>': 16,
#  '소 소 한</w>': 76,
#  '일 탈 이</w>': 3,
#  '잔잔한</w>': 319,
#  '미 소 를</w>': 30,
#  '머 금 게</w>': 3,
#  '합니다</w>': 244,
#  '음악 은</w>': 51,
#  '조금</w>': 478,
#  '아쉽 네요</w>': 98,
#  '주고</w>': 311,
#  '싶 은데</w>': 95,
#  '평점</w>': 1810,
#  '올 리고</w>': 13,
#  '싶 어</w>': 53,
#  '줄 게 요</w>': 2,
#  '평점 에 속 지마 시 길 시간 낭비</w>': 1,
#  '돈 낭비 임</w>': 2,
#  '리 얼 리 티 가</w>': 14,
#  '뛰어 나 긴</w>': 1,
#  '한데</w>': 123,
#  '큰</w>': 376,
#  '공감 은</w>': 22,
#  '안 간다</w>': 69,
#  '이 민 기 캐릭터 는</w>': 1,
#  '정신 의 학 상</w>': 1,
#  '분 노 조 절 장 애</w>': 2,
#  '초 기</w>': 12,
#  '증 상 일 거 다</w>': 1,
#  '툭 하면</w>': 12,
#  '사람 패 고</w>': 2,
#  '욕 하고</w>': 24,
#  '물 건</w>': 2,
#  '파 손 하고</w>': 1,
#  '오 바 였 음</w>': 2,
#  '극</w>': 24,
#  '초반 엔</w>': 47,
#  '신선 했는데</w>': 7,
#  '가 면</w>': 58,
#  '이 민 기</w>': 14,
#  '정신 상 태</w>': 4,
#  '공감 불 가</w>': 2,
#  '마이 너 스 는</w>': 23,
#  '왜 없 냐</w>': 2,
#  '뮤 비</w>': 6,
#  '보고</w>': 2628,
#  '영화 수준</w>': 7,
#  '딱</w>': 566,
#  '알 만 하 더 군</w>': 1,
#  '북 한 에서</w>': 5,
#  '이런 거</w>': 157,
#  '만들 라고</w>': 8,
#  '돈</w>': 400,
#  '대 주 던</w>': 1,
#  '난</w>': 1427,
#  '우리 영화를</w>': 1,
#  '사랑 합니다</w>': 61,
#  '데 너 리스</w>': 1,
#  '타 르</w>': 2,
#  '가 르 엔 나도</w>': 1,
#  '용 의 주인이</w>': 1,
#  '되고</w>': 119,
#  '싶 다 누 이 랑 근 친 상 간 이나</w>': 1,
#  '하고</w>': 812,
#  '다 닐 지 라 도 소설</w>': 1,
#  '속 에선</w>': 2,
#  '제일</w>': 645,
#  '놈 이</w>': 23,
#  '자 이 메</w>': 1,
#  '라 니 스터 였 는데 드라마 속 에 선 드 래 곤 용 이</w>': 1,
#  '멋지 네 웃음 감독 님</w>': 1,
#  '토 르</w>': 10,
#  '다 크</w>': 13,
#  '월 드는</w>': 1,
#  '말 아</w>': 12,
#  '잡 수 셨 을 지 라 도 기 본</w>': 1,
#  '선 방 은</w>': 1,
#  '했음</w>': 63,
#  '사람 의</w>': 148,
#  '영 혼 을</w>': 27,
#  '어 루 만 져</w>': 2,
#  '줄</w>': 520,
#  '수도</w>': 131,
#  '있 군요</w>': 13,
#  '거 친</w>': 19,
#  '세상 사 를</w>': 1,
#  '잠 시</w>': 45,
#  '잊 고</w>': 57,
#  '동 화 같은</w>': 45,
#  '영화에</w>': 648,
#  '행복 했 네요</w>': 1,
#  '야</w>': 83,
#  '세 르 게 이</w>': 6,
#  '작 은 고 추 의</w>': 2,
#  '매 운 맛 을</w>': 4,
#  '보여주 마</w>': 4,
#  '포 퐁 저 그</w>': 1,
#  '콩 진 호 가</w>': 5,
#  '간다</w>': 93,
#  '가슴 시리 게</w>': 1,
#  '드라마 가</w>': 185,
#  '있을까</w>': 289,
#  '감동</w>': 686,
#  '그</w>': 2442,
#  '자체</w>': 104,
#  '난 또</w>': 6,
#  '저</w>': 342,
#  '꼬 마 애 가</w>': 3,
#  '무슨</w>': 1054,
#  '원 한 이</w>': 2,
#  '깊 길래</w>': 1,
#  '했 더니</w>': 51,
#  '혼 자</w>': 177,
#  '나 대 다</w>': 1,
#  '걸</w>': 329,
#  '어쩌 라고</w>': 34,
#  '재미있어요</w>': 288,
#  '전</w>': 455,
#  '좋아요</w>': 399,
#  '충격 적이 엇 다</w>': 1,
#  '기분 을</w>': 16,
#  '완전 히</w>': 109,
#  '푹</w>': 89,
#  '꺼 지 게</w>': 2,
#  '하는</w>': 1266,
#  '느낌</w>': 660,
#  '활 력 이라 고는</w>': 1,
#  '없는</w>': 2028,
#  '무 거 운 지 독 하고</w>': 1,
#  '차 갑 고</w>': 7,
#  '무 자 비 하다</w>': 1,
#  '그저</w>': 466,
#  '일본 인 들의</w>': 3,
#  '상상 력 은</w>': 14,
#  '대단 한거</w>': 3,
#  '같 다는</w>': 24,
#  '생각이</w>': 462,
#  '든다</w>': 160,
#  '심 심 한영화</w>': 2,
#  '백 봉 기</w>': 1,
#  '언제 나오 나요</w>': 2,
#  '보는내내</w>': 486,
#  '그대로</w>': 275,
#  '들어 맞 는</w>': 6,
#  '예 측</w>': 14,
#  '카 리스 마</w>': 48,
#  '악 역</w>': 35,
#  '불 알 이</w>': 1,
#  '나와서</w>': 308,
#  '당 황 아무 튼</w>': 1,
#  '중간에</w>': 311,
#  '끝나는</w>': 100,
#  '평범 함 속에</w>': 3,
#  '녹 아 든</w>': 6,
#  '일 상</w>': 27,
#  '밋 밋 한게</w>': 2,
#  '흠</w>': 134,
#  '보 던 거 라</w>': 1,
#  '계 속 보고 있는데</w>': 1,
#  '전개도</w>': 101,
#  '느 리고</w>': 32,
#  '주인공 인</w>': 19,
#  '은 희 는</w>': 1,
#  '한 두 컷</w>': 1,
#  '나오 면서</w>': 21,
#  '소 극 적 인 모습 에</w>': 1,
#  '짜증 이</w>': 60,
#  '맨 날</w>': 100,
#  '언제 끝나 나</w>': 4,
#  '기대 만 하고 있어요</w>': 1,
#  '전개 좀</w>': 1,
#  '빨 리 빨 리</w>': 4,
#  '사랑 하고싶 게 하는 가슴 속 온 감정 을 헤 집 어 놓 는 영화 예 요 정말 최고</w>': 1,
#  '많은</w>': 748,
#  '사람들이</w>': 332,
#  '다큐 를</w>': 36,
#  '우리나라</w>': 304,
#  '슬 픈</w>': 166,
#  '현 대사 의</w>': 3,
#  '한</w>': 1354,
#  '단 면 에</w>': 3,
#  '대해</w>': 335,
#  '깊 이</w>': 85,
#  '생각 하고</w>': 116,
#  '사 죄 하고</w>': 1,
#  '바로</w>': 315,
#  '잡 기</w>': 3,
#  '위해</w>': 422,
#  '노 력 했 으면</w>': 1,
#  '말 로 만</w>': 8,
#  '듣 던</w>': 7,
#  '보 도 연 맹</w>': 1,
#  '민 간 인</w>': 5,
#  '학 살 이</w>': 2,
#  '이정도</w>': 110,
#  '일</w>': 102,
#  '줄 이야</w>': 46,
#  '명 백 한</w>': 14,
#  '살인 입니다</w>': 1,
#  '살인 자 들은</w>': 1,
#  '어디 있 나요</w>': 1,
#  '예 전</w>': 72,
#  '작품</w>': 954,
#  '캐릭터</w>': 225,
#  '에 피 소 드</w>': 40,
#  '재 탕</w>': 11,
#  '삼 탕</w>': 3,
#  '사 골 우 려 먹 듯</w>': 1,
#  '우리고</w>': 2,
#  '내용은</w>': 396,
#  '산 으로</w>': 107,
#  '가고</w>': 67,
#  '시청 률 은</w>': 16,
#  '아 예 안 나오 고</w>': 1,
#  '이제</w>': 493,
#  '회 중 반 인데</w>': 1,
#  '부 작 이라 니</w>': 2,
#  '김 남 길 의</w>': 3,
#  '백 점 짜리</w>': 1,
#  '연기력 과</w>': 42,
#  '초반</w>': 116,
#  '몰입 도 에도</w>': 1,
#  '불 구 하고</w>': 133,
#  '손 예 진</w>': 17,
#  '재밌 네</w>': 112,
#  '비슷 한</w>': 175,
#  '영화를</w>': 2803,
#  '안 보 신</w>': 9,
#  '분 들 한 테 는</w>': 1,
#  '재미있을</w>': 26,
#  '노래 실 력 으로 뽑 는게</w>': 1,
#  '맞 냐</w>': 13,
#  '박 시 환 이</w>': 2,
#  '나 가 면</w>': 5,
#  '망 신 이다</w>': 3,
#  '일본 영화</w>': 82,
#  '다 이런 건가</w>': 1,
#  '유치 하다</w>': 96,
#  '이 틀 만에</w>': 6,
#  '봤어요</w>': 405,
#  '재밌어요</w>': 551,
#  '근데</w>': 701,
#  '차</w>': 38,
#  '안 에</w>': 89,
#  '넣 어</w>': 18,
#  '조 작 하려고</w>': 1,
#  '하면</w>': 218,
#  '안 이</w>': 2,
#  '열 려 있 다 던 지</w>': 1,
#  '집</w>': 37,
#  '활 짝</w>': 7,
#  '열 려서</w>': 1,
#  '아무 나</w>': 45,
#  '들어 간 다 던 가</w>': 1,
#  '문 자 를</w>': 1,
#  '조 작 하려 고 하면</w>': 1,
#  '비 번 이</w>': 2,
#  '안</w>': 938,
#  '걸 려 있고</w>': 1,
#  '그런</w>': 512,
#  '억지 스러 웠 는데</w>': 2,
#  '그래도</w>': 774,
#  '내용</w>': 490,
#  '자체 는</w>': 83,
#  '졸작</w>': 293,
#  '재밋 네요</w>': 37,
#  '달 팽 이가</w>': 3,
#  '빨 라서</w>': 11,
#  '더</w>': 3274,
#  '재밌었 어요</w>': 184,
#  '어설픈</w>': 341,
#  '전개</w>': 312,
#  '어이 없는</w>': 161,
#  '결말</w>': 303,
#  '부 패 한</w>': 6,
#  '로 마 노 프</w>': 1,
#  '왕 조 를</w>': 1,
#  '기 리는</w>': 4,
#  '뭣 같은</w>': 6,
#  '온 몸 으로</w>': 5,
#  '항 거 했던</w>': 1,
#  '러 시 아</w>': 32,
#  '민 중 들이</w>': 1,
#  '폭 도 냐</w>': 1,
#  '내용 전개 는</w>': 3,
#  '무 난 한</w>': 19,
#  '편 이였 구</w>': 1,
#  '보았 습니다</w>': 85,
#  '매우</w>': 429,
#  '실망</w>': 211,
#  '한국 영화</w>': 204,
#  '흥 행 코 드</w>': 1,
#  '갈 등 갈 등 계 에 속</w>': 1,
#  '갈 등 화 해 감동</w>': 1,
#  '남 발</w>': 9,
#  '흥 행</w>': 40,
#  '뻔 하지</w>': 16,
#  '뭐</w>': 1066,
#  '아 햏 햏</w>': 3,
#  '뭐 냐 시작 하고</w>': 1,
#  '분 만에</w>': 57,
#  '나왔 다</w>': 61,
#  '리 플 릿</w>': 1,
#  '사 진</w>': 22,
#  '보 며</w>': 107,
#  '불 안 하 더 니 만</w>': 1,
#  '단 연</w>': 102,
#  '최고 라고</w>': 51,
#  '할수 있 지</w>': 4,
#  '감독이</w>': 598,
#  '럼 먹 고</w>': 1,
#  '만들었 나 보다</w>': 3,
#  '관객 에게</w>': 34,
#  '뭘</w>': 386,
#  '말 하는 지도</w>': 3,
#  '모르겠 고</w>': 113,
#  '엉 망 진 창</w>': 19,
#  '개 진 창 이다</w>': 1,
#  '뭐냐</w>': 243,
#  '우 뢰 매 냐</w>': 1,
#  '정말 쓰레기 영화입니다</w>': 1,
#  '진정</w>': 93,
#  '위 대한</w>': 111,
#  '최고 임</w>': 85,
#  '별 루</w>': 98,
#  '였다</w>': 39,
#  '내 일이</w>': 11,
#  '기대 되는</w>': 32,
#  '조 미 가</w>': 1,
#  '막 문 위</w>': 1,
#  '좋아 한 건 가요</w>': 1,
#  '골 깜</w>': 1,
#  '눈</w>': 104,
#  '부 라 릴 때</w>': 1,
#  '쓰 러 짐</w>': 1,
#  '성 룡 영화중</w>': 9,
#  '최악 인듯</w>': 9,
#  '골 때 리 네</w>': 4,
#  '걸 스 데 이</w>': 2,
#  '이 혜 리</w>': 1,
#  '되 라</w>': 7,
#  '서 기 가 이 뻐 서</w>': 1,
#  '재밌 어요 백 인 공 주 귀여 움</w>': 1,
#  '인상 적인</w>': 59,
#  '영화였다</w>': 308,
#  '어 내 스트 와</w>': 1,
#  '셀 레 스 틴</w>': 2,
#  '강 추 에요</w>': 5,
#  '재밌 습니다</w>': 145,
#  '재미있는 영화입니다</w>': 1,
#  '클 라 라 볼 라 고 화 신 본 거 아닌 데</w>': 1,
#  '슬 펐 던</w>': 15,
#  '영화다</w>': 1077,
#  '설정이</w>': 55,
#  '재밌고</w>': 364,
#  '새 로운</w>': 259,
#  '내 에서</w>': 6,
#  '메 인</w>': 14,
#  '차 차</w>': 1,
#  '나오 는게</w>': 21,
#  '재밌음</w>': 409,
#  '신 카 이</w>': 4,
#  '마 코 토 의</w>': 1,
#  '작 화 와 미 유 와</w>': 1,
#  '하나 카 나 가</w>': 1,
#  '연기를</w>': 372,
#  '잘 해 줘 서</w>': 3,
#  '더 대박 이였다</w>': 1,
#  '재미없음</w>': 350,
#  '진심</w>': 510,
#  '이 훨 나</w>': 1,
#  '캐스팅 두 못 한 듯</w>': 1,
#  '잔잔 한게</w>': 9,
#  '생각보다</w>': 324,
#  '볼만한</w>': 261,
#  '영화인 거</w>': 27,
#  '같 습니다</w>': 180,
#  '감독 님 들</w>': 2,
#  '고 은 님</w>': 1,
#  '쓰 면</w>': 20,
#  '영화 안 봅 니다</w>': 1,
#  '무섭 지도</w>': 102,
#  '않았 고</w>': 29,
#  '영화 속</w>': 51,
#  '억지 스럽 고</w>': 50,
#  '노 골 적인</w>': 12,
#  '술 광 고 를</w>': 1,
#  '좀</w>': 2566,
#  '은 은 하고</w>': 3,
#  '센 스 있게</w>': 2,
#  '했 으면</w>': 80,
#  '어 땠 을까</w>': 25,
#  '킬링타임</w>': 53,
#  '크 리스 마 스 하면</w>': 2,
#  '떠 오 르 는영화</w>': 1,
#  '재미있게</w>': 753,
#  '봤습니다</w>': 527,
#  '매력 적인</w>': 168,
#  '행복 이네요</w>': 1,
#  '음악 에</w>': 28,
#  '빠져 서</w>': 58,
#  '볼</w>': 959,
#  '있었 던</w>': 158,
#  '쫌</w>': 117,
#  '산 만 하 긴</w>': 2,
#  '하 던데</w>': 35,
#  '태 어 나서</w>': 75,
#  '처음 으로</w>': 212,
#  '영화보다</w>': 208,
#  '나왔 습니다 불 륜 이</w>': 1,
#  '로맨 스 냐</w>': 3,
#  '왕 짜증 아주</w>': 1,
#  '전개 를</w>': 22,
#  '짬 뽕 으로</w>': 1,
#  '믹 스 했 구 나 음 향 만</w>': 1,
#  '무섭 게 하 네 하 아</w>': 1,
#  '별 루 더라</w>': 1,
#  '시간 낭비 느낌</w>': 1,
#  '대박</w>': 481,
#  '시청 률</w>': 102,
#  '기 준 이</w>': 16,
#  '되는</w>': 452,
#  '패 널 가 구 들</w>': 1,
#  '머 하는거 지</w>': 1,
#  '명작 드라마</w>': 2,
#  '망 치 네</w>': 10,
#  '서 운 하다</w>': 1,
#  '내용이</w>': 636,
#  '이상 해</w>': 33,
#  '몬 스터</w>': 10,
#  '주 식 회 사</w>': 2,
#  '재밌게</w>': 1349,
#  '봤다</w>': 707,
#  '내용 전개가</w>': 26,
#  '너무나</w>': 454,
#  '느 리 다</w>': 9,
#  '소재 는</w>': 187,
#  '흥미 를</w>': 55,
#  '끌 지만</w>': 2,
#  '이야기</w>': 695,
#  '전개가</w>': 251,
#  '투 박 해서</w>': 2,
#  '몰입 이</w>': 140,
#  '안되는 군</w>': 6,
#  '보지마 라</w>': 83,
#  '쓰레기</w>': 1519,
#  '중국 인</w>': 10,
#  '특 유 의</w>': 215,
#  '과 장</w>': 7,
#  '허 풍</w>': 4,
#  '있어 보이 려고</w>': 12,
#  '안 간 힘</w>': 2,
#  '쓴</w>': 135,
#  '노 력 은</w>': 21,
#  '가 상 하나</w>': 3,
#  '고 증 과</w>': 2,
#  '현실 감</w>': 18,
#  '떨어지는</w>': 139,
#  '거 북 스럽다</w>': 2,
#  '도대체</w>': 570,
#  '그 들은</w>': 34,
#  '이 렇게 까지</w>': 47,
#  '스 스 로 를</w>': 17,
#  '과 대 포 장 하는</w>': 1,
#  '것 인지</w>': 26,
#  '불 법 체 류 자</w>': 7,
#  '때 려 잡 는</w>': 6,
#  '영화 면</w>': 26,
#  '좋았 을 텐 데 무슨</w>': 1,
#  '우 상 화 를</w>': 1,
#  '만든 다고</w>': 10,
#  '미국 의</w>': 64,
#  '따뜻 한</w>': 227,
#  '설정 이건</w>': 1,
#  '뭥 미</w>': 55,
#  '년 의</w>': 21,
#  '삶 속에</w>': 3,
#  '주인공 의</w>': 159,
#  '생 애 가</w>': 2,
#  '전 부</w>': 235,
#  '드 러 난</w>': 16,
#  '하다</w>': 262,
#  '별 점 점 가 자</w>': 1,
#  '별로 다</w>': 162,
#  '본 지</w>': 70,
#  '지 난</w>': 164,
#  '후 에</w>': 57,
#  '남 기 지만 재미있었 음</w>': 1,
#  '아니</w>': 341,
#  '이게</w>': 1745,
#  '점대</w>': 139,
#  '일 까</w>': 7,
#  '년이</w>': 230,
#  '지나</w>': 36,
#  '보게 된</w>': 44,
#  '다시 봐도</w>': 242,
#  '순수 한</w>': 165,
#  '사랑 에</w>': 148,
#  '숀 펜 의</w>': 4,
#  '연기 또 한</w>': 6,
#  '올 레 에</w>': 2,
#  '공 짜 로 있 길래</w>': 1,
#  '봤음</w>': 248,
#  '헐</w>': 164,
#  '스토리가</w>': 675,
#  '문제 가 아니라</w>': 1,
#  '연기 자 들이</w>': 16,
#  '전혀</w>': 882,
#  '배 역 이랑</w>': 2,
#  '어울 리 지않 음</w>': 1,
#  '그리고</w>': 1592,
#  '상 대 배우들 하고</w>': 1,
#  '따 로</w>': 68,
#  '노 는거 같음</w>': 1,
#  '연기 자 들도</w>': 10,
#  '문제 있음</w>': 1,
#  '보 아 는</w>': 3,
#  '별로 임</w>': 85,
#  '라 미 란 하고</w>': 1,
#  '아 들이</w>': 61,
#  '젤</w>': 120,
#  '볼만 했음</w>': 27,
#  '욕 심 이</w>': 18,
#  '많 았 던</w>': 24,
#  '어느</w>': 194,
#  '쪽 만 이라도</w>': 1,
#  '보여 줬 다면</w>': 3,
#  '빵 점</w>': 51,
#  '베 댓 이</w>': 2,
#  '말 을</w>': 124,
#  '아주</w>': 845,
#  '잘 써 놨 네</w>': 1,
#  '모 자 라 진</w>': 1,
#  '않다</w>': 321,
#  '도 둑 들이나</w>': 2,
#  '뫼 비 우 스</w>': 3,
#  '나라 에서</w>': 10,
#  '만들어 졌 다는게</w>': 5,
#  '믿 어지 냐</w>': 1,
#  '온 몸 이</w>': 6,
#  '찌 릿 짜 릿</w>': 1,
#  '나 두</w>': 15,
#  '용 기를</w>': 21,
#  '가 져 야지</w>': 1,
#  '정말 재미있고</w>': 2,
#  '교훈 적인</w>': 16,
#  '영화이네요</w>': 7,
#  '당시 의</w>': 24,
#  '상황 과</w>': 22,
#  '주제 를</w>': 84,
#  '주 입 식 이</w>': 1,
#  '긴장감 있고</w>': 11,
#  '전 하는</w>': 14,
#  '케이 블 에서</w>': 74,
#  '그 만</w>': 226,
#  '나와 줬 으면</w>': 4,
#  '다르 덴 이 냐 리 투 차 이 밍 량 이</w>': 1,
#  '안 섞 인 채</w>': 1,
#  '짬 뽕</w>': 13,
#  '그 릇 에</w>': 2,
#  '담 겨 있다</w>': 10,
#  '여 군</w>': 4,
#  '잼 없음</w>': 35,
#  '뭐 하는 건지</w>': 8,
#  '엠 비 씨</w>': 11,
#  '다 잼 없음</w>': 1,
#  '질 린 다 이제</w>': 1,
#  '좋 구나</w>': 9,
#  '한 석 규</w>': 21,
#  '김 혜 수</w>': 22,
#  '연기 만</w>': 45,
#  '돋 보 인</w>': 20,
#  '어 딘 지</w>': 5,
#  '모르 게</w>': 105,
#  '많이</w>': 1492,
#  '에 볼 라 바 이러 스가</w>': 1,
#  '떠 들 석 해서</w>': 1,
#  '보게 된 영화인데</w>': 2,
#  '작품 성 이나</w>': 3,
#  '어 떤 면 에서도</w>': 1,
#  '여 년 전</w>': 18,
#  '영화라 고 보기 엔</w>': 1,
#  '믿 기 힘들 정도로</w>': 1,
#  '잘 만들었 다고 본다</w>': 1,
#  '마지막 후반 부 가</w>': 1,
#  '살 짝</w>': 143,
#  '아쉽 긴 하지만</w>': 5,
#  '이정도 면</w>': 150,
#  '수작 이라 고 본다</w>': 1,
#  '시간이</w>': 633,
#  '아깝 지않 은 영화</w>': 3,
#  '볼만 해</w>': 10,
#  '재미있 다고</w>': 30,
#  '떨 지</w>': 1,
#  '마 세요</w>': 129,
#  '용 가 리</w>': 16,
#  '진짜 짱 짱 맨 이다</w>': 1,
#  '이제 서 야</w>': 93,
#  '보다니</w>': 65,
#  '감 히</w>': 96,
#  '내</w>': 1616,
#  '인생</w>': 416,
#  '최고의</w>': 2235,
#  '하나 로</w>': 74,
#  '꼽 을</w>': 19,
#  '있을 만한</w>': 3,
#  '어떻게</w>': 755,
#  '살아 야 할 지</w>': 4,
#  '나 를</w>': 176,
#  '고 민 을</w>': 18,
#  '하게</w>': 190,
#  '시간</w>': 812,
#  '모 건</w>': 8,
#  '프 리 먼 은</w>': 1,
#  '나이가</w>': 64,
#  '들어도</w>': 38,
#  '여 전 히</w>': 173,
#  '섹 시 하다</w>': 15,
#  '작가 가 별로 다</w>': 1,
#  '내용 이 진짜 별로 임</w>': 1,
#  '맨 날 그냥 기대 하고</w>': 1,
#  '재 방송 하면</w>': 1,
#  '혹 시나 하고 봐 줘 도</w>': 1,
#  '답 없다 진짜</w>': 1,
#  '명작 도</w>': 11,
#  '이런</w>': 3292,
#  '명작 이</w>': 52,
#  '싶다</w>': 571,
#  '봐도</w>': 911,
#  '여운이</w>': 576,
#  '남는</w>': 500,
#  '조금 만</w>': 50,
#  '손</w>': 37,
#  '왠 만한</w>': 54,
#  '상 업</w>': 10,
#  '못 지</w>': 20,
#  '않 게</w>': 136,
#  '퀄 리 티</w>': 41,
#  '쩔 게</w>': 4,
#  '만들어</w>': 224,
#  '질</w>': 33,
#  '있었는데</w>': 86,
#  '충분 히</w>': 271,
#  '재미있었 습니다</w>': 58,
#  '개인적으로</w>': 479,
#  '잔인 하게</w>': 27,
#  '자 극 적으로</w>': 9,
#  '노 출 씬 도</w>': 2,
#  '화 끈 하게</w>': 26,
#  '했 더라면</w>': 6,
#  '국 산 영화라</w>': 1,
#  '아 낀</w>': 2,
#  '보 임</w>': 26,
#  '그 만 좀</w>': 21,
#  '끌 고</w>': 37,
#  '끝 내 라</w>': 7,
#  '지 겹 다</w>': 61,
#  '지 겨 워</w>': 20,
#  '역시</w>': 1532,
#  '드 니 로 의</w>': 12,
#  '연기는</w>': 486,
#  '일 품</w>': 44,
#  '나도</w>': 559,
#  '맥 스가</w>': 1,
#  '샘 을</w>': 3,
#  '죽 이 길</w>': 1,
#  '바 랬 다</w>': 6,
#  '괜찮은</w>': 441,
#  '작품 입니다</w>': 63,
#  '좋은</w>': 1747,
#  '스러 웟 음</w>': 1,
#  '배우들은</w>': 81,
#  '지 네 들</w>': 3,
#  '안 뜨 니까</w>': 1,
#  '이런 영화</w>': 163,
#  '찍 을 껀 데</w>': 1,
#  '안 뜨 는지</w>': 1,
#  '모르 는거 야</w>': 1,
#  '면 상</w>': 5,
#  '알 겠 구만</w>': 1,
#  '지 네</w>': 8,
#  '자신 들은</w>': 3,
#  '모 를 까</w>': 20,
#  '어린 이가</w>': 5,
#  '좋아 할 듯 내 어릴 적</w>': 1,
#  '동 심 은</w>': 3,
#  '멀 리</w>': 12,
#  '떠 낫 나 보다</w>': 1,
#  '무 술 인이</w>': 2,
#  '총 을 드 나</w>': 1,
#  '크 리스토 퍼 왈 츠 와</w>': 1,
#  '타 란 티 노 의</w>': 10,
#  '조 합 이란</w>': 2,
#  '한국 에 선 유 명 한 편 은 아니 지만</w>': 1,
#  '외 국 에선</w>': 2,
#  '상상 초 월 한</w>': 1,
#  '유 명 한</w>': 107,
#  '영화입니다</w>': 576,
#  '오랜만에</w>': 568,
#  '재밋 는 영화 봤네요</w>': 1,
#  '종 방 되 어</w>': 1,
#  '아쉬 워요</w>': 44,
#  '오늘 막 방 도</w>': 1,
#  '잘 봤 어요 방송 대 본 이</w>': 1,
#  '완 성 도 있 다는</w>': 1,
#  '느낌 받 았 고 요</w>': 1,
#  ...}

# %% [markdown]
# **BPE**를 활용한 토크나이즈는 **최장 길이 토큰의 매칭**을 우선적으로 적용하기 때문에,
#
# 사전을 **단어 길이 기준**의 **내림차순**으로 정렬해줘야 합니다. 이를 위해 `get_token_len` 함수를 구현해줍니다.

# %%
def get_token_len(token: str):
    """토큰 길이 계산: </w> 는 하나의 토큰 취급"""
    if token.endswith("</w>"):
        # 구성 캐릭터 + </w>
        return len(token[:-4]) + 1
    return len(token)

# %% [markdown]
# 이제 구축된 사전을 활용해 새로운 입력 값을 토크나이즈 할 수 있는 `tokenize` 함수를 구현하도록 합니다.
#
# **BPE**를 활용한 문장의 인코딩은 **재귀적으로** 구성되기 때문에, 직접 결과 값을 찍어보며 이해하는 것이 가장 좋습니다.
#
# `tokenize`의 기본적인 로직은 다음과 같습니다.
#
# 1. 훈련을 통해 구축된 **단어 리스트**를 순회하며, 입력 문장 내 해당 단어가 존재하는지 파악합니다.
# 2. 순회하던 단어가 입력 문장 내에 **존재하지 않는다면**, 계속 순회를 진행합니다.
#     - 만약 단어 리스트를 끝까지 순회했음에도 매치되는 토큰이 없었다면, `</u>`의 **OOV** 토큰을 반환합니다.
# 2. 순회하던 단어가 입력 문장 내에 **존재한다면**, 해당 토큰을 기준으로 **재귀적인** 토크나이즈를 수행합니다.
#     - 먼저, 매치 토큰의 좌측 스팬을 **서브 스트링**으로 설정해 토크나이즈 함수에 입력합니다. 그리그 그 결과를 전체 결과 리스트에 추가합니다.
#     - 이제, **매칭된 토큰**을 결과 값에 추가합니다.
#     - **매치 토큰**이 한 문장 내에서 여러 개일 수 있으므로, 위 과정을 여러 번 반복합니다.
#     - 이후 매치 토큰 우측 스팬을 **서브 스트링**으로 설정해 토크나이즈 함수에 입력합니다. 그리그 그 결과를 전체 결과 리스트에 추가합니다.

# %%
def tokenize(text: str, sorted_tokens: List[str], unknown_token="</u>"):
    """구축된 사전을 활용한 BPE 토크나이즈"""
    text = text.strip()

    if text == "":
        return list()
    if len(sorted_tokens) == 0:
        return [unknown_token]

    result = list()
    # 사전 내 등록 단어 순회
    for i in range(len(sorted_tokens)):
        token = re.escape(sorted_tokens[i])

        # 현재 순회 중인 단어가 입력 텍스트에 포함되는지 확인
        matched = [(m.start(0), m.end(0)) for m in re.finditer(token, text)]

        ## 단순히 포함되지 않은 것이라면, continue
        ## 토큰 리스트를 다 돌았음에도 포함되지 않은 것이라면, [unk] 반환
        if len(matched) == 0:
            if i == (len(sorted_tokens) - 1):
                return [unknown_token]
            else:
                continue

        ## 포함되면 해당 토큰의 시작점(들)을 저장
        ends = [m[0] for m in matched]
        print(f"[{text}] 매치 토큰: {token} / 인덱스: {ends}")

        start = 0
        for end in ends:
            # 매치 토큰 이전에 위치한 서브 스트링에 대한 토크나이즈 진행 및 결과 추가
            substring = text[start:end]
            print(f"[{text}] 서브 스트링: {substring} ({start}~{end})")
            result += tokenize(substring, sorted_tokens[i+1:])

            # 매치 토큰 추가
            result += [token]
            print(f"[{text}] 현재 토크나이즈 결과: {result}")

            # 매치 토큰 길이 만큼 start 인덱스 값 증가
            start = end + len(token)

        # 매치 토큰 이후에 위치한 서브 스트링에 대한 토크나이즈 진행 및 결과 추가
        remainder = text[start:]
        result += tokenize(remainder, sorted_tokens[i+1:])
        break
    return result

# %% [markdown]
# 구현한 `tokenize` 함수를 활용해 새로운 입력 값에 대한 인코딩을 진행해보도록 합시다.
#
# 앞서 언급한대로 **입력 값**을 바꾸어 가며, **결과 값**을 찍어보는 것이 이해에 가장 도움이 됩니다.

# %%
tokens = get_tokens(vocab)

# 사전 내 토큰들 길이 순으로 정렬 후, 단어만 저장
sorted_tokens = sorted(tokens.items(), key=lambda x: (get_token_len(x[0]), x[1]), reverse=True)
sorted_tokens = [token for (token, _) in sorted_tokens]

print(f"사전 내 등록 단어:\n{sorted_tokens}\n")

words = ["한한국ㅑ한국한국국ㅖ", "사랑합니다</w>", "야식</w> 안먹고</w> 참아보기</w>"]

for word in words:
    print(f"입력 단어: {format(word)}\n")
    print(f"입력 단어 토큰화 결과: {tokenize(word, sorted_tokens)}\n")
# Out:
# 사전 내 등록 단어:
# ['재미없다시간이</w>', '배우들이었는데</w>', '재미있었는데</w>', '재미없었는데</w>', '마지막장면이</w>', '재미없는영화</w>', '재미있는영화</w>', '재미없다는거</w>', '배우들이나와</w>', '지마지막장면</w>', '존재미있어요</w>', '습니다시간이</w>', '재미없다는게</w>', '니다니다니다</w>', '까지만들어서</w>', '재미없다는지</w>', '습니다가슴이</w>', '영화이야기는</w>', '드라마이네요</w>', '배우들이해도</w>', '드라마이라고</w>', '배우들이네요</w>', '배우들이지만</w>', '정말이영화는</w>', '영상영화라고</w>', '많이하는영화</w>', '영화이영화를</w>', '기대한다는거</w>', '가지만으로도</w>', '더라이영화로</w>', '파이영화라고</w>', '영화입니다</w>', '개인적으로</w>', '영화관에서</w>', '재미있어요</w>', '쓰레기영화</w>', '애니메이션</w>', '재밌었는데</w>', '재미있었다</w>', '모르겠지만</w>', '재미없어서</w>', '재미없었다</w>', '여주인공이</w>', '재미있는데</w>', '재미없다고</w>', '재미없네요</w>', '재미있어서</w>', '만들었는데</w>', '영화이지만</w>', '마지막장면</w>', '재미없는데</w>', '드라마지만</w>', '재미없다는</w>', '재미없는건</w>', '배우들에게</w>', '잼있었는데</w>', '재미있지만</w>', '재미있을듯</w>', '드라마이다</w>', '기대한다면</w>', '안되는영화</w>', '영화이네요</w>', '만들어지는</w>', '배우들이라</w>', '재미없는게</w>', '결말이지만</w>', '재미있는건</w>', '재미없는지</w>', '재미없다는거', '결말이라도</w>', '드라마이고</w>', '재미있는게</w>', '재미없는거</w>', '배우들이나</w>', '재미있는지</w>', '만들어지고</w>', '배우연기도</w>', '재미있어야</w>', '만들어지지</w>', '힘들어지는</w>', '재미있는거</w>', '재미없다니</w>', '배우연기는</w>', '재미없다면</w>', '많이나와서</w>', '들이었는데</w>', '힘들었는데</w>', '드라마이런</w>', '습니다시간</w>', '재미없다가</w>', '배우들이고</w>', '가지않았다</w>', '전개그리고</w>', '이영화인데</w>', '결말이라고</w>', '라이영화는</w>', '이다시간이</w>', '재미있을까</w>', '영화이였다</w>', '이영화보다</w>', '웃기다는거</w>', '결말이네요</w>', '재미없다시간', '결말이었다</w>', '이하는영화</w>', '연출연기다</w>', '이영화라고</w>', '배우연기를</w>', '드라마이걸</w>', '라이영화에</w>', '영화이해가</w>', '들이야기가</w>', '성우연기는</w>', '남자연기를</w>', '까지마지막</w>', '들이나와서</w>', '나라이렇게</w>', '가지마이건</w>', '이영화인가</w>', '화이야기를</w>', '만들어지나</w>', '없다시나리오', '이영화이후</w>', '연출연기대사', '드라마이게</w>', '영화이었다</w>', '하다시간이</w>', '파이영화라</w>', '니다가슴이</w>', '많이나온다</w>', '배우들이나왔', '배우연기력</w>', '한다시나리오', '한다는영화</w>', '나오랜만에</w>', '이영화라는</w>', '만화이네요</w>', '어이영화다</w>', '배우들이란</w>', '파이하겠다</w>', '결말이였다</w>', '파이영화중</w>', '아이영화가</w>', '하다시나리오', '결말이라서</w>', '배우들이랑</w>', '하나이지만</w>', '아이영화는</w>', '라이영화를</w>', '지마지막에</w>', '드라마이면</w>', '파이영화가</w>', '웃기다는건</w>', '이영화이지</w>', '다시나리오</w>', '드라마이거</w>', '존재미없어</w>', '까지만드는</w>', '한다가슴이</w>', '마이영화가</w>', '여자연기가</w>', '돌아버리지</w>', '니다시간이</w>', '이영화이다</w>', '살아버리는</w>', '많이하는데</w>', '적이었는데</w>', '정말이라는</w>', '돌아버리는</w>', '연출연기가</w>', '드라마이건</w>', '이하나라는</w>', '배우들이다</w>', '왜이영화를</w>', '결말이라면</w>', '말이영화를</w>', '성우연기가</w>', '배우들어이제', '전개연기도</w>', '네이영화를</w>', '지마지막장면', '많이하는지</w>', '하다가슴이</w>', '영화이라고</w>', '시대사람들</w>', '안되었는데</w>', '이다가슴이</w>', '영화이렇게</w>', '연출연기도</w>', '이다시나리오', '드라이하고</w>', '잼있는영화</w>', '봤습니다</w>', '재미있게</w>', '스토리가</w>', '재미없다</w>', '아름다운</w>', '영화라고</w>', '재밌어요</w>', '스토리도</w>', '배우들의</w>', '마지막에</w>', '오랜만에</w>', '지루하고</w>', '보는내내</w>', '좋아하는</w>', '극장에서</w>', '영화네요</w>', '모르겠다</w>', '지루하다</w>', '재미없음</w>', '사람들이</w>', '배우들이</w>', '영화인데</w>', '스토리는</w>', '영화였다</w>', '생각보다</w>', '사람들은</w>', '감동적인</w>', '보여주는</w>', '주인공이</w>', '우리나라</w>', '재미있다</w>', '재밌네요</w>', '애니메이션', '영화보다</w>', '만으로도</w>', '이영화를</w>', '재미있는</w>', '이영화는</w>', '재미없는</w>', '이야기를</w>', '시나리오</w>', '재밌었다</w>', '재미있고</w>', '재미없고</w>', '이야기가</w>', '보고싶다</w>', '영화이다</w>', '스토리를</w>', '재미있음</w>', '재미없어</w>', '이영화가</w>', '만들었다</w>', '여주인공</w>', '왜이렇게</w>', '떨어지는</w>', '연기력이</w>', '배우들도</w>', '재미없네</w>', '보고싶은</w>', '있었는데</w>', '영화인듯</w>', '쓰레기다</w>', '만들어도</w>', '이야기는</w>', '영화인지</w>', '영화라는</w>', '배우들은</w>', '긴장감이</w>', '잼있어요</w>', '없는영화</w>', '적이네요</w>', '적이었다</w>', '영화인가</w>', '정말이지</w>', '보여주고</w>', '떨어지고</w>', '하는영화</w>', '것같아요</w>', '만들어서</w>', '배우들을</w>', '영화라서</w>', '이었는데</w>', '있는영화</w>', '마지막장면', '괜찮았다</w>', '지않는다</w>', '쓰레기는</w>', '드라마다</w>', '이영화의</w>', '보이지만</w>', '킬링타임</w>', '쓰레기를</w>', '재미있어요', '되었는데</w>', '없었는데</w>', '영화라면</w>', '적이지만</w>', '이야기도</w>', '이야기에</w>', '것같은데</w>', '하고싶다</w>', '하겠지만</w>', '이영화에</w>', '쓰레기가</w>', '힘들었다</w>', '하고싶은</w>', '되는영화</w>', '재미있어</w>', '보이네요</w>', '안되는데</w>', '없다는게</w>', '이정도로</w>', '들이라면</w>', '영화라도</w>', '습니다만</w>', '지않았다</w>', '한다는게</w>', '들었는데</w>', '적이였다</w>', '재미있을</w>', '적이라고</w>', '잼있었다</w>', '쓰레기도</w>', '배우들과</w>', '적이라는</w>', '잼있는데</w> ...
# 입력 단어: 한한국ㅑ한국한국국ㅖ
#
# [한한국ㅑ한국한국국ㅖ] 매치 토큰: 한국 / 인덱스: [1, 4, 6]
# [한한국ㅑ한국한국국ㅖ] 서브 스트링: 한 (0~1)
# [한] 매치 토큰: 한 / 인덱스: [0]
# [한] 서브 스트링:  (0~0)
# [한] 현재 토크나이즈 결과: ['한']
# [한한국ㅑ한국한국국ㅖ] 현재 토크나이즈 결과: ['한', '한국']
# [한한국ㅑ한국한국국ㅖ] 서브 스트링: ㅑ (3~4)
# [한한국ㅑ한국한국국ㅖ] 현재 토크나이즈 결과: ['한', '한국', '</u>', '한국']
# [한한국ㅑ한국한국국ㅖ] 서브 스트링:  (6~6)
# [한한국ㅑ한국한국국ㅖ] 현재 토크나이즈 결과: ['한', '한국', '</u>', '한국', '한국']
# [국ㅖ] 매치 토큰: 국 / 인덱스: [0]
# [국ㅖ] 서브 스트링:  (0~0)
# [국ㅖ] 현재 토크나이즈 결과: ['국']
# 입력 단어 토큰화 결과: ['한', '한국', '</u>', '한국', '한국', '국', '</u>']
#
# 입력 단어: 사랑합니다</w>
#
# [사랑합니다</w>] 매치 토큰: 합니다</w> / 인덱스: [2]
# [사랑합니다</w>] 서브 스트링: 사랑 (0~2)
# [사랑] 매치 토큰: 사랑 / 인덱스: [0]
# [사랑] 서브 스트링:  (0~0)
# [사랑] 현재 토크나이즈 결과: ['사랑']
# [사랑합니다</w>] 현재 토크나이즈 결과: ['사랑', '합니다</w>']
# 입력 단어 토큰화 결과: ['사랑', '합니다</w>']
#
# 입력 단어: 야식</w> 안먹고</w> 참아보기</w>
#
# [야식</w> 안먹고</w> 참아보기</w>] 매치 토큰: 보기</w> / 인덱스: [17]
# [야식</w> 안먹고</w> 참아보기</w>] 서브 스트링: 야식</w> 안먹고</w> 참아 (0~17)
# [야식</w> 안먹고</w> 참아] 매치 토큰: 고</w> / 인덱스: [9]
# [야식</w> 안먹고</w> 참아] 서브 스트링: 야식</w> 안먹 (0~9)
# [야식</w> 안먹] 매치 토큰: 식</w> / 인덱스: [1]
# [야식</w> 안먹] 서브 스트링: 야 (0~1)
# [야] 매치 토큰: 야 / 인덱스: [0]
# [야] 서브 스트링:  (0~0)
# [야] 현재 토크나이즈 결과: ['야']
# [야식</w> 안먹] 현재 토크나이즈 결과: ['야', '식</w>']
# [안먹] 매치 토큰: 안 / 인덱스: [0]
# [안먹] 서브 스트링:  (0~0)
# [안먹] 현재 토크나이즈 결과: ['안']
# [먹] 매치 토큰: 먹 / 인덱스: [0]
# [먹] 서브 스트링:  (0~0)
# [먹] 현재 토크나이즈 결과: ['먹']
# [야식</w> 안먹고</w> 참아] 현재 토크나이즈 결과: ['야', '식</w>', '안', '먹', '고</w>']
# [참아] 매치 토큰: 아 / 인덱스: [1]
# [참아] 서브 스트링: 참 (0~1)
# [참] 매치 토큰: 참 / 인덱스: [0]
# [참] 서브 스트링:  (0~0)
# [참] 현재 토크나이즈 결과: ['참']
# [참아] 현재 토크나이즈 결과: ['참', '아']
# [야식</w> 안먹고</w> 참아보기</w>] 현재 토크나이즈 결과: ['야', '식</w>', '안', '먹', '고</w>', '참', '아', '보기</w>']
# 입력 단어 토큰화 결과: ['야', '식</w>', '안', '먹', '고</w>', '참', '아', '보기</w>']

# %% [markdown]
# 이상으로 **Byte-Pair Encoding**을 한국어에 적용했을 때, 사전이 어떤 식으로 구축되는지에 대해 알아보았습니다.
#
# 위 코드는 이해를 돕기 위해 작성된 것이기 때문에 실제 프로젝트에 **BPE**를 적용하고자 한다면, 저자의 [**공식 구현체**](https://github.com/rsennrich/subword-nmt)를 사용하시는 것이 좋을 것 같습니다.

# %% [markdown]
# ### 참조
# - [Lei Mao's Byte-Pair Encoding](https://leimao.github.io/blog/Byte-Pair-Encoding/)
# - [Neural Machine Translation of Rare Words with Subword Units](https://arxiv.org/abs/1508.07909)
# - [subword-nmt](https://github.com/rsennrich/subword-nmt)
# - [nsmc](https://github.com/e9t/nsmc)
